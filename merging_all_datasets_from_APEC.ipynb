# %% [markdown]
# ### Scrapping des données :

# %%
import pandas as pd

# %%
dev_df = pd.read_csv("./Scrapped_Data/Data_Apec/Apec_dev.csv")
ia_df = pd.read_csv("./Scrapped_Data/Data_Apec/Apec_ia_data_scientist_analyst_engineer.csv")
reseau_df = pd.read_csv("./Scrapped_Data/Data_Apec/Apec_reseau_total.csv")
data_df = pd.read_csv("Scrapped_Data/Merge_data_cybSec_ancienne/Apec_data_total_merged.csv")

# %%
# Concaténation des DataFrames
concatenated_df = pd.concat([dev_df,ia_df,reseau_df,data_df])

# Suppression des doublons
concatenated_df = concatenated_df.drop_duplicates()
concatenated_df
# Out:
#                              entreprise            type_contrat  \
# 0     MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 1     MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 2                          Marion PINEL                1 \n CDI
# 3                             SESAME IT                2 \n CDI
# 4                              Adsearch                1 \n CDI
# ...                                 ...                     ...
# 9204                                  1                1 \n CDI
# 9205        Grand Calais Terres et Mers                1 \n CDI
# 9207                    Q ENERGY France                1 \n CDI
# 9208               REGION ILE DE FRANCE  1 \n CDD \n de 36 mois
# 9209                            ARTELIA                1 \n CDI
#
#               deparetement       date_publication          date_mise_a_jour  \
# 0     Aix-en-Provence - 13  Publiée le 29/02/2024  Actualisée le 29/02/2024
# ...

# %%
metiers_a_filtrer = ['Data analyst',
    'Chief Data Officer', 
    'Business analyst',
    'Data engineer', 
    'Administrateur data center', 
    'Ingénieur développement BI', 
    'Administrateur de bases de données',
    'Data scientist', 
    'Architecte Big Data', 
    'Web analyst',
    'Chef de projet informatique décisionnelle', 
    'Ingénieur sécurité informatique', 
    'Ingénieur test et recettes', 
    'Architecte infrastructures', 
    'Responsable sécurité informatique', 
    'Chef de projet informatique', 
    'Développeur', 
    'Ingénieur système',
    'Architecte développement', 
    'Administrateur système',
    'Business developer',
    'Ingénieur réseaux',
    'Ingénieur informatique embarquée',
    'Ingénieur traitement du signal' ,
    'Directeur de projets informatiques',
    'Ingénieur système',
    'Développeur',
    'Ingénieur sécurité informatique',
    'Ingénieur en études et développement informatiques',
    'Ingénieur réseaux',
    'Ingénieur informatique industrielle',
    'Ingénieur R&D',
    'Chef de projet informatique',
    'Architecte infrastructures',
    'Ingénieur informatique embarquée',
    'Administrateur système',
    'Ingénieur test et essai',
    'Ingénieur télécoms',
    'Business developer',
    'Ingénieur calcul et structure',
    'Ingénieur qualité',
    'Ingénieur process',
    'Consultant technique progiciel',
    'Ingénieur d\'affaires en informatique',
    'Chef de projet travaux',
    'Analyste financier',
    'Architecte développement',
    'Responsable informatique',
    'Chef de projet Agile',
    'Ingénieur test et recettes',
    'Ingénieur de maintenance informatique',
    'Ingénieur intégration progiciel',
    'Administrateur réseaux',
    'Ingénieur de production informatique',
    'Architecte système',
    'Administrateur de bases de données',
    'Responsable sécurité informatique',
    'Business manager',
    'Chef de projet digital',
    'Architecte réseaux',
    'Project management officer',
    'Chef de projet R&D',
    'Chef de projet fonctionnel web',
    'Data engineer',
    'Directeur de projets informatiques',
    'Consultant en cybersécurité',
    'Business analyst',
    'Chief Data Officer',
    'Data analyst',
    'Administrateur data center',
    'Ingénieur développement BI',
    'Data scientist',
    'Délégué à la protection des données',
    'Pricing analyst',
    'Statisticien',
    'Architecte Big Data'
]
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
# Filtrer les lignes où la colonne "métier" contient l'un des métiers de la liste
df_filtre = concatenated_df[concatenated_df['metier'].isin(metiers_a_filtrer)]
df_filtre
# Out:
#                                    entreprise            type_contrat  \
# 0           MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 1           MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 2                                Marion PINEL                1 \n CDI
# 3                                   SESAME IT                2 \n CDI
# 4                                    Adsearch                1 \n CDI
# ...                                       ...                     ...
# 9190  Caisse Nationale de l'Assurance Maladie                1 \n CDI
# 9192   CENTRE HOSPITALIER UNIVERSITAIRE REIMS                1 \n CDI
# 9199                        AMARIS FRANCE SAS                1 \n CDI
# 9204                                        1                1 \n CDI
# 9208                     REGION ILE DE FRANCE  1 \n CDD \n de 36 mois
#
#               deparetement       date_publication          date_mise_a_jour  \
# ...

# %%
# from IPython.display import display
# pd.set_option('display.max_rows', None)
df_filtre.to_csv(f'Scrapped_Data/Data_APEC_all/all_data_V1.csv', index=False)
