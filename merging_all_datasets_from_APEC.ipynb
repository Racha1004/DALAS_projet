# %% [markdown]
# ### Scrapping des données :

# %%
import pandas as pd

# %%
dev_df = pd.read_csv("./Scrapped_Data/Data_Apec/Apec_dev.csv")
ia_df = pd.read_csv("./Scrapped_Data/Data_Apec/Apec_ia_data_scientist_analyst_engineer.csv")
reseau_df = pd.read_csv("./Scrapped_Data/Data_Apec/Apec_reseau_total.csv")
data_df = pd.read_csv("Scrapped_Data/Merge_data_cybSec_ancienne/Apec_data_total_merged.csv")

# %%
type_metier_filtred_unique = concatenated_df["metier"].unique()
type_metier_filtred_unique
# Out:
# array(['Développeur', 'Architecte développement', 'Business developer',
#        'Data engineer', 'Data scientist', 'Data analyst',
#        'Consultant en cybersécurité', 'Directeur développement durable',
#        "Chargé d'affaires dans le BTP", 'Ingénieur industrialisation',
#        'Ingénieur électronique', 'Ingénieur intégration progiciel',
#        'Ingénieur test et recettes',
#        "Ingénieur d'affaires en informatique", 'Ingénieur test et essai',
#        'Ingénieur travaux', 'Enseignant', 'Ingénieur HSE',
#        'Ingénieur informatique industrielle', "Ingénieur d'études du BTP",
#        "Consultant maîtrise d'ouvrage", 'Ingénieur sécurité informatique',
#        'Ingénieur support des ventes',
#        "Responsable d'exploitation transport", 'Responsable informatique',
#        'Commercial', 'Chef de projet informatique',
#        'Acheteur de prestations intellectuelles', 'Analyste financier',
#        'Responsable support technique', 'Business analyst',
#        'Ingénieur R&D', 'Ingénieur process', "Chargé d'affaires",
#        'Ingénieur télécoms', 'Chef de projet digital',
#        'Conseiller développement économique', 'Administrateur système',
#        'Chargé de financement de projet',
#        'Directeur des infrastructures et de la production informatique',
#        'Responsable de formation', 'Architecte système', 'Juriste',
#        'Ingénieur mécanique', 'Ingénieur études de prix',
#        'Key account manager',
#        'Ingénieur en études et développement informatiques',
#        'Chargé de recrutement', 'Ingénieur informatique embarquée',
#        'Chef de projet R&D BTP', 'Dessinateur projeteur',
#        'Conducteur de travaux', 'Ingénieur de maintenance informatique',
#        'Avocat', 'Ingénieur généraliste', 'Ingénieur génie électrique',
#        'Hydraulicien', 'Responsable maintenance',
#        "Responsable d'atelier de production",
#        "Urbaniste du système d'information", 'Ingénieur qualité',
#        'Chef de service socio-éducatif', 'Responsable des achats',
#        'Chef de projet R&D',
#        "Chargé d'affaires en environnement et énergie",
#        'Chef de projet travaux', 'Directeur industriel',
#        'Ingénieur avant-vente', 'Architecte infrastructures',
#        'Responsable RH', 'Ingénieur génie civil', 'Logisticien',
#        'Ingénieur calcul et structure', 'Chef de projet fonctionnel web',
#        'Responsable développement du réseau commercial',
#        "Ingénieur d'études environnement", 'Ingénieur mécatronique',
#        'Technico-commercial', 'Commercial export',
#        'Ingénieur de production industrielle',
#        "Ingénieur d'études réseaux d'énergie", 'Trader',
#        'Business manager', "Chargé d'affaires dans l'industrie",
#        'Responsable services généraux', 'Consultant technique progiciel',
#        'Ingénieur CVC', 'Responsable de programmes immobiliers',
#        'Chef de rayon', "Chargé d'affaires dans la santé",
#        'Ingénieur amélioration continue', 'Acheteur industriel',
#        'Project management officer', 'Chef de projet Agile',
#        'Géotechnicien', 'Ingénieur de production informatique',
#        'Ingénieur système', 'Directeur de projets informatiques',
#        'Adjoint de direction', 'Rédacteur',
#        "Responsable de bureau d'études", 'Chef de produit',
#        'Directeur commercial', 'Ingénieur travaux neufs',
#        'Ingénieur chimiste', 'Expert en environnement et écologie',
#        'Responsable des relations sociales',
#        'Responsable marketing digital', 'Consultant SIRH',
#        'Ingénieur en maintenance industrielle',
#        'Responsable de la relation clients',
#        'Ingénieur énergies renouvelables',
#        "Chargé d'intelligence économique",
#        'Responsable administratif et financier',
#        'Chef de projet aménagement du territoire', 'Responsable HSE',
#        'Ingénieur sûreté de fonctionnement', 'Directeur des travaux',
#        'Ingénieur intégration validation',
#        'Chef de projet informatique industrielle', 'Acheteur',
#        'Architecte (BTP)', 'Ingénieur instrumentation',
#        'Développeur foncier', 'Comptable',
#        'Chef de projet sites et sols pollués',
#        'Responsable qualité achats', 'Géologue',
#        'Ingénieur en simulation numérique', 'Ingénieur sûreté nucléaire',
#        "Directeur d'exploitation énergie",
#        'Ingénieur en efficacité énergétique',
#        'Ingénieur maintenance des équipements énergétiques',
#        'Directeur administratif et financier', 'Ingénieur planification',
#        'Ingénieur agroalimentaire', 'Ingénieur énergies',
#        'Responsable commercial', 'Chargé des relations publiques',
#        'Directeur de la relation clients', 'Consultant en recrutement',
#        'Géomètre topographe', 'Chef de projet informatique décisionnelle',
#        'Conseiller en gestion de patrimoine', 'Incident manager',
#        'Ingénieur radio', 'Ingénieur procédés',
#        'Chargé de mission commerciale', 'Responsable middle office',
#        'Contrôleur de gestion', 'Chef de secteur commercial',
#        'Responsable méthodes et industrialisation',
#        "Trésorier d'entreprise", 'Chef de chantier', 'Responsable R&D',
#        'Asset manager', 'Géomaticien', "Directeur d'unité de production",
#        'Ingénieur matériaux',
#        'Chef de projet ergonomie et prévention des risques professionnels',
#        'Directeur études, recherche et développement', 'Actuaire',
#        'Supply planner', 'Ingénieur brevets', 'Directeur marketing',
#        'Responsable sécurité informatique', 'Projeteur BIM',
#        'Responsable service après vente', 'Administrateur réseaux',
#        'Banquier conseil M&A', 'Chief Data Officer',
#        "Responsable d'études marketing",
#        "Directeur des systèmes d'information",
#        'Gestionnaire parc automobile et matériel',
#        'Chargé de communication', 'Promoteur des ventes',
#        'Responsable du recrutement', 'Gestionnaire CRM',
#        'Approvisionneur', "Ingénieur d'affaires en ingénierie",
#        'Chercheur en informatique et mathématiques', 'Statisticien',
#        'Responsable de production industrielle',
#        "Conducteur d'opérations", 'Ingénieur poste de travail',
#        'Chargé des affaires réglementaires',
#        'Administrateur de bases de données',
#        'Directeur technique industrielle', 'Ingénieur réseaux',
#        'Responsable maintenance industrielle', 'BIM manager',
#        'Prévisionniste de ventes', 'Responsable logistique',
#        'Directeur de centre de profit', 'Directeur commercial régional',
#        'Métrologue', "Chargé d'études actuarielles",
#        'Commercial en assurances', 'Responsable marketing',
#        'Responsable mécénat', 'Formateur', 'Directeur export',
#        'Ingénieur biologiste', 'Responsable mobilité internationale',
#        'Architecte réseaux', 'Responsable de la diversité',
#        "Chargé d'appels d'offres", 'Assureur qualité', 'Urbaniste',
#        'Designer', 'Responsable ordonnancement et planification',
#        'Gestionnaire back office', 'Auditeur externe',
#        'Ingénieur optique', 'Juriste social', 'Responsable qualité',
#        'Architecte Big Data', 'Rédacteur technique', 'Acheteur projet',
#        "Chargé d'études socio-économiques", 'Administrateur data center',
#        'Chargé de référencement web', 'Contract manager',
#        'Directeur commercial et marketing', 'Ingénieur mise en service',
#        'Consultant logistique', 'Ingénieur plasturgie',
#        'Directeur du développement commercial',
#        'Pharmacien de production', 'Consultant en assurance',
#        "Directeur d'établissement d'accueil de jeunes enfants",
#        "Directeur d'établissement social", 'Chargé de la qualité',
#        'Ingénieur développement BI', 'Généraliste RH',
#        'Ingénieur packaging', "Responsable d'agence commerciale",
#        'Directeur général', 'Consultant finance', 'Commercial immobilier',
#        'Consultant qualité', 'Directeur de start-up', 'Assistant achats',
#        'Gestionnaire de la supply chain',
#        'Conseiller clientèle en banque', 'Ingénieur métallurgiste',
#        'Chargé de relation client', 'Consultant en organisation',
#        'Acheteur public', 'Responsable centre de la relation clients',
#        'Attaché de recherche clinique', 'Auditeur interne',
#        'Responsable MOA', "Consultant en management d'entreprise",
#        'Souscripteur assurance', 'Pricing analyst',
#        'Chargé de conformité', 'Chef de projet marketing', 'Acheteur BTP',
#        'Assistant commercial', "Consultant en management de l'innovation",
#        'Économiste de la construction', 'Risk manager',
#        'Gestionnaire de flux logistiques',
#        "Responsable d'agence immobilière", 'Directeur QHSE',
#        'Community manager',
#        'Responsable technique maintenance et entretien',
#        'Assistant de gestion', 'Directeur de la supply chain',
#        'Assistant de direction', 'Gestionnaire administration des ventes',
#        'Ingénieur biomédical', 'Chargé de formation',
#        "Chef d'équipe commerciale", 'Architecte naval',
#        'Consultant commercial',
#        'Responsable préparation et réception - expédition',
#        'Ingénieur motoriste', 'Conseiller en évolution professionnelle',
#        'Responsable de la gestion des carrières', 'Chef des ventes',
#        'Responsable gestion des stocks', 'Traducteur', 'Retail manager',
#        'Ingénieur traitement du signal',
#        'Délégué à la protection des données', 'Web analyst',
#        'Documentaliste', 'Directeur de la communication',
#        'Analyste crédit', 'Responsable trésorerie',
#        "Chargé d'études marketing", 'Responsable du contrôle de gestion',
#        'Chef de projet en organisation', "Directeur d'association",
#        'Responsable de parc informatique', 'Cadre de santé',
#        'Responsable de restaurant', 'Agent de transport',
#        'Ingénieur développement de composants', 'Cartographe',
#        "Agent général d'assurances", 'Assistant RH', 'Conseiller social',
#        'Ingénieur en biotechnologies', 'Gestionnaire immobilier',
#        "Directeur d'exploitation BTP", 'Assistant social',
#        'Responsable comptable', 'Médecin spécialiste',
#        'Médecin de prévention',
#        "Responsable de laboratoire d'analyses R&D",
#        'Médecin pharmacien biologiste', 'Chef de produit digital',
#        'Homologateur', "Architecte d'intérieur", 'Consultant PLM',
#        'Directeur des ressources humaines',
#        'Responsable développement de franchise', 'Animateur des ventes',
#        'Responsable commercial régional', 'Responsable conditionnement',
#        'Category manager', 'Manager commercial', 'Directeur immobilier',
#        'Responsable SIRH', "Responsable d'hébergement touristique",
#        'Webmaster', 'Directeur comptable', 'Responsable sécurité privée',
#        'Gestionnaire de paie', "Expert d'assurances", 'Ingénieur soudeur',
#        "Directeur d'agence BTP", 'Animateur SAV',
#        'Contrôleur de gestion sociale',
#        'Architecte business intelligence',
#        'Responsable administration du personnel', 'Pharmacien',
#        'Brand content manager', 'Orthophoniste', 'UX designer',
#        'Graphiste', 'Biostatisticien', 'Chef de publicité',
#        'Responsable paie', 'Gestionnaire de copropriété', 'Fiscaliste',
#        'Directeur des achats', 'Traffic manager', 'Chef de cuisine',
#        'Assistant juridique', 'Psychologue', 'Infirmier',
#        'Risk manager bancaire', 'Chargé de facturation clients',
#        'Chargé de recouvrement', 'Ergothérapeute',
#        'Chargé de conformité bancaire', 'Travel manager',
#        "Directeur d'établissement médico-social",
#        'Chargé de mission médico-social', 'Médecin coordonnateur',
#        'Assistant marketing', 'Médecin généraliste',
#        'Social media manager', "Chargé d'affaires dans la formation",
#        'Ingénieur méthode informatique', 'Courtier en assurances',
#        'Directeur de maison de retraite', 'Chef de service médical',
#        'Gestionnaire de sinistres', 'Médecin DIM',
#        'Responsable de magasin', 'Directeur de centre socio-culturel',
#        'Chef de projet événementiel', 'Clerc de notaire',
#        'Pharmacien assurance qualité', 'Chargé de pharmacovigilance',
#        'Délégué médical', 'Merchandiser', 'Expert comptable', 'Éditeur',
#        'Responsable de production informatique',
#        'Directeur de pôle médico-social', 'Responsable juridique',
#        "Responsable d'agence services à la personne",
#        'Chargé de médiation culturelle', 'Responsable rémunérations',
#        'Expert MOA banque', 'Conseiller clientèle en assurances',
#        'Géophysicien', "Directeur d'hôpital", 'Psychologue du travail',
#        'Journaliste', 'Ingénieur formulation', 'acousticien',
#        "Délégué de l'assurance maladie", 'Designer industriel',
#        'Responsable de développement touristique', 'Directeur des soins',
#        'Yield manager', 'Cadre supérieur de santé',
#        'Planneur stratégique', "Gestionnaire de contrats d'assurance",
#        'Web designer', 'Consultant en communication', 'Affréteur',
#        'Contrôleur des coûts'], dtype=object)

# %%
# Concaténation des DataFrames
concatenated_df = pd.concat([dev_df,ia_df,reseau_df,data_df])

# Suppression des doublons
concatenated_df = concatenated_df.drop_duplicates()
concatenated_df
# Out:
#                              entreprise            type_contrat  \
# 0     MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 1     MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 2                          Marion PINEL                1 \n CDI
# 3                             SESAME IT                2 \n CDI
# 4                              Adsearch                1 \n CDI
# ...                                 ...                     ...
# 9204                                  1                1 \n CDI
# 9205        Grand Calais Terres et Mers                1 \n CDI
# 9207                    Q ENERGY France                1 \n CDI
# 9208               REGION ILE DE FRANCE  1 \n CDD \n de 36 mois
# 9209                            ARTELIA                1 \n CDI
#
#               deparetement       date_publication          date_mise_a_jour  \
# 0     Aix-en-Provence - 13  Publiée le 29/02/2024  Actualisée le 29/02/2024
# 1              Rennes - 35  Publiée le 16/03/2024  Actualisée le 16/03/2024
# 2             Limoges - 87  Publiée le 28/02/2024  Actualisée le 28/02/2024
# 3            Paris 17 - 75  Publiée le 06/02/2024  Actualisée le 11/03/2024
# 4               Rouen - 76  Publiée le 15/03/2024  Actualisée le 15/03/2024
# ...                    ...                    ...                       ...
# 9204              Belgique  Publiée le 23/01/2024  Actualisée le 15/03/2024
# 9205           Calais - 62  Publiée le 14/03/2024  Actualisée le 14/03/2024
# 9207          Avignon - 84  Publiée le 21/02/2024  Actualisée le 21/02/2024
# 9208       Saint-Ouen - 93  Publiée le 16/02/2024  Actualisée le 16/02/2024
# 9209    Choisy-le-Roi - 94  Publiée le 26/02/2024  Actualisée le 26/02/2024
#
#                             salaire    prise_de_poste  \
# 0            35 - 45 k€ brut annuel  Dès que possible
# 1            35 - 42 k€ brut annuel  Dès que possible
# 2     A partir de 36 k€ brut annuel  Dès que possible
# 3            45 - 55 k€ brut annuel  Dès que possible
# 4            33 - 40 k€ brut annuel  Dès que possible
# ...                             ...               ...
# 9204                     A négocier  Dès que possible
# 9205                     A négocier  Dès que possible
# 9207                     A négocier  Dès que possible
# 9208                     A négocier  Dès que possible
# 9209                     A négocier  Dès que possible
#
#                     experience                                     metier  \
# 0     Aucune expérience exigée                                Développeur
# 1     Aucune expérience exigée                                Développeur
# 2                Minimum 5 ans                                Développeur
# 3                Minimum 5 ans                                Développeur
# 4                Minimum 2 ans                                Développeur
# ...                        ...                                        ...
# 9204             Minimum 8 ans                     Chef de projet travaux
# 9205             Minimum 3 ans            Directeur développement durable
# 9207             Minimum 5 ans                    Responsable maintenance
# 9208             Minimum 2 ans  Chef de projet informatique décisionnelle
# 9209            Minimum 10 ans      Responsable de programmes immobiliers
#
#                        statut_du_poste zone_de_deplacement  \
# 0               Cadre du secteur privé  Pas de déplacement
# 1               Cadre du secteur privé  Pas de déplacement
# 2               Cadre du secteur privé  Pas de déplacement
# 3               Cadre du secteur privé  Pas de déplacement
# 4               Cadre du secteur privé  Pas de déplacement
# ...                                ...                 ...
# 9204            Cadre du secteur privé    Union Européenne
# 9205  Cadre du secteur public / Armées  Pas de déplacement
# 9207            Cadre du secteur privé           Régionale
# 9208  Cadre du secteur public / Armées  Pas de déplacement
# 9209            Cadre du secteur privé  Pas de déplacement
#
#                                      secteur_d_activite        Teletravail  \
# 0     ACCUEIL OU ACCOMPAGNEMENT SANS HÉBERGEMENT D'A...                NaN
# 1     ACCUEIL OU ACCOMPAGNEMENT SANS HÉBERGEMENT D'A...                NaN
# 2                          FORMATION CONTINUE D'ADULTES   Partiel possible
# 3                            PROGRAMMATION INFORMATIQUE       Non autorisé
# 4     ACTIVITÉS DES AGENCES DE PLACEMENT DE MAIN-D'O...                NaN
# ...                                                 ...                ...
# 9204         FABRICATION D'AUTRES MATÉRIELS ÉLECTRIQUES   Partiel possible
# 9205                   ADMINISTRATION PUBLIQUE GÉNÉRALE                NaN
# 9207                      INGÉNIERIE, ÉTUDES TECHNIQUES   Partiel possible
# 9208                   ADMINISTRATION PUBLIQUE GÉNÉRALE  Ponctuel autorisé
# 9209                      INGÉNIERIE, ÉTUDES TECHNIQUES                NaN
#
#                                        descriptif_poste  \
# 0     En tant que Développeur Web vos fonctions sero...
# 1     Vous intégrez une équipe agile en tant que Dév...
# 2     Nous recherchons un développeur web (H/F) tale...
# 3     Pour venir supporter notre activité en hyper c...
# 4     Notre client est un acteur majeur de l’héberge...
# ...                                                 ...
# 9204  La succursale belge d’Hitachi Rail renforce se...
# 9205  Missions globales :\nLe/La Responsable de la S...
# 9207  Vos missions : Rattaché.e au Responsable Procu...
# 9208  Mission 1 : Pilotage des projets numériques du...
# 9209  Au sein de la branche Grands Equipements Fonct...
#
#                                        profil_recherche  \
# 0     De formation supérieure en informatique, vous ...
# 1     Diplômé d'un Bac +5 en informatique minimum, v...
# 2     Connaissances :\nIl/Elle dispose de très bonne...
# 3     Ton profil :\nDe formation Ingénieur ou diplôm...
# 4     VOTRE PROFIL\nVous avez une formation Bac +3 /...
# ...                                                 ...
# 9204  De formation Master, vous êtes diplômé d'une é...
# 9205  Vous êtes?\nTitulaire d'une formation en Envir...
# 9207  Votre profil : Vous êtes diplômé.e d’une école...
# 9208  Savoir-faire :\nCapacité à conduire un projet ...
# 9209  Qualifications\n\nProfil\nVous avez le profil ...
#
#                                    langues  \
# 0               ['Aucune langue attendue']
# 1               ['Aucune langue attendue']
# 2                  ['Français', 'Anglais']
# 3               ['Aucune langue attendue']
# 4               ['Aucune langue attendue']
# ...                                    ...
# 9204  ['Anglais', 'Français', 'Voir plus']
# 9205            ['Aucune langue attendue']
# 9207               ['Anglais', 'Français']
# 9208            ['Aucune langue attendue']
# 9209            ['Aucune langue attendue']
#
#                                             savoir_etre  \
# 0     ['Autonomie', "Capacité d'analyse", 'Capacité ...
# 1     ['Curiosité', "Esprit d'équipe", 'Force de pro...
# 2     ['Autonomie', 'Créativité', "Esprit d'équipe",...
# 3     ['Autonomie', 'Capacité à travailler en mode p...
# 4     ['Autonomie', 'Proactivité', "Sens de l'engage...
# ...                                                 ...
# 9204        ['Curiosité', 'Leadership', 'Persévérance']
# 9205  ['Autonomie', 'Capacité à résoudre des problèm...
# 9207  ['Autonomie', 'Capacité à prendre des décision...
# 9208  ["Capacité d'adaptation", 'Capacité de communi...
# 9209           ['Autonomie', 'Motivation', 'Pédagogie']
#
#                                            savoir_faire  \
# 0     ['Application Web', 'Développement web', 'Info...
# 1     ['Développement web', 'CakePHP', 'CQRS', 'DDD'...
# 2     ['Angular JS', 'Apache', 'Application Web', 'A...
# 3     ['Base de données', 'Interface de programmatio...
# 4     ['Automatisme', 'Cappuccino', 'Économie', 'Fra...
# ...                                                 ...
# 9204  ['Ferroviaire', 'Gestion de planning', 'Gestio...
# 9205  ['Règlementations', 'Bureautique', 'Actions de...
# 9207  ['Base de données', 'Microsoft Access', 'Micro...
# 9208  ['Formation continue et professionnelle', 'QS'...
# 9209  ['Acoustique', 'Administratif', 'Architecture'...
#
#                                   descriptif_entreprise
# 0     Notre client est un éditeur de logiciels dans ...
# 1     Notre client, éditeur de logiciel dynamique, r...
# 2     L'Office International de l'Eau (OiEau, www.oi...
# 3     Spécialiste de l'anticipation des menaces, Ses...
# 4     Adsearch vous propose des milliers d''opportun...
# ...                                                 ...
# 9204  Hitachi Rail est un fournisseur mondial de sol...
# 9205  Située au coeur de la Côte d'Opale, proche du ...
# 9207  Qui sommes-nous ?  Q ENERGY France est un acte...
# 9208  Employeur de premier plan, la Région Ile-de-Fr...
# 9209  Qui sommes-nous ?\nNous sommes un groupe d'ing...
#
# [15733 rows x 19 columns]

# %%
type_metier_filtred_unique = concatenated_df["metier"].unique()
type_metier_filtred_unique
# Out:
# array(['Développeur', 'Architecte développement', 'Business developer',
#        'Data engineer', 'Data scientist', 'Data analyst',
#        'Consultant en cybersécurité', 'Directeur développement durable',
#        "Chargé d'affaires dans le BTP", 'Ingénieur industrialisation',
#        'Ingénieur électronique', 'Ingénieur intégration progiciel',
#        'Ingénieur test et recettes',
#        "Ingénieur d'affaires en informatique", 'Ingénieur test et essai',
#        'Ingénieur travaux', 'Enseignant', 'Ingénieur HSE',
#        'Ingénieur informatique industrielle', "Ingénieur d'études du BTP",
#        "Consultant maîtrise d'ouvrage", 'Ingénieur sécurité informatique',
#        'Ingénieur support des ventes',
#        "Responsable d'exploitation transport", 'Responsable informatique',
#        'Commercial', 'Chef de projet informatique',
#        'Acheteur de prestations intellectuelles', 'Analyste financier',
#        'Responsable support technique', 'Business analyst',
#        'Ingénieur R&D', 'Ingénieur process', "Chargé d'affaires",
#        'Ingénieur télécoms', 'Chef de projet digital',
#        'Conseiller développement économique', 'Administrateur système',
#        'Chargé de financement de projet',
#        'Directeur des infrastructures et de la production informatique',
#        'Responsable de formation', 'Architecte système', 'Juriste',
#        'Ingénieur mécanique', 'Ingénieur études de prix',
#        'Key account manager',
#        'Ingénieur en études et développement informatiques',
#        'Chargé de recrutement', 'Ingénieur informatique embarquée',
#        'Chef de projet R&D BTP', 'Dessinateur projeteur',
#        'Conducteur de travaux', 'Ingénieur de maintenance informatique',
#        'Avocat', 'Ingénieur généraliste', 'Ingénieur génie électrique',
#        'Hydraulicien', 'Responsable maintenance',
#        "Responsable d'atelier de production",
#        "Urbaniste du système d'information", 'Ingénieur qualité',
#        'Chef de service socio-éducatif', 'Responsable des achats',
#        'Chef de projet R&D',
#        "Chargé d'affaires en environnement et énergie",
#        'Chef de projet travaux', 'Directeur industriel',
#        'Ingénieur avant-vente', 'Architecte infrastructures',
#        'Responsable RH', 'Ingénieur génie civil', 'Logisticien',
#        'Ingénieur calcul et structure', 'Chef de projet fonctionnel web',
#        'Responsable développement du réseau commercial',
#        "Ingénieur d'études environnement", 'Ingénieur mécatronique',
#        'Technico-commercial', 'Commercial export',
#        'Ingénieur de production industrielle',
#        "Ingénieur d'études réseaux d'énergie", 'Trader',
#        'Business manager', "Chargé d'affaires dans l'industrie",
#        'Responsable services généraux', 'Consultant technique progiciel',
#        'Ingénieur CVC', 'Responsable de programmes immobiliers',
#        'Chef de rayon', "Chargé d'affaires dans la santé",
#        'Ingénieur amélioration continue', 'Acheteur industriel',
#        'Project management officer', 'Chef de projet Agile',
#        'Géotechnicien', 'Ingénieur de production informatique',
#        'Ingénieur système', 'Directeur de projets informatiques',
#        'Adjoint de direction', 'Rédacteur',
#        "Responsable de bureau d'études", 'Chef de produit',
#        'Directeur commercial', 'Ingénieur travaux neufs',
#        'Ingénieur chimiste', 'Expert en environnement et écologie',
#        'Responsable des relations sociales',
#        'Responsable marketing digital', 'Consultant SIRH',
#        'Ingénieur en maintenance industrielle',
#        'Responsable de la relation clients',
#        'Ingénieur énergies renouvelables',
#        "Chargé d'intelligence économique",
#        'Responsable administratif et financier',
#        'Chef de projet aménagement du territoire', 'Responsable HSE',
#        'Ingénieur sûreté de fonctionnement', 'Directeur des travaux',
#        'Ingénieur intégration validation',
#        'Chef de projet informatique industrielle', 'Acheteur',
#        'Architecte (BTP)', 'Ingénieur instrumentation',
#        'Développeur foncier', 'Comptable',
#        'Chef de projet sites et sols pollués',
#        'Responsable qualité achats', 'Géologue',
#        'Ingénieur en simulation numérique', 'Ingénieur sûreté nucléaire',
#        "Directeur d'exploitation énergie",
#        'Ingénieur en efficacité énergétique',
#        'Ingénieur maintenance des équipements énergétiques',
#        'Directeur administratif et financier', 'Ingénieur planification',
#        'Ingénieur agroalimentaire', 'Ingénieur énergies',
#        'Responsable commercial', 'Chargé des relations publiques',
#        'Directeur de la relation clients', 'Consultant en recrutement',
#        'Géomètre topographe', 'Chef de projet informatique décisionnelle',
#        'Conseiller en gestion de patrimoine', 'Incident manager',
#        'Ingénieur radio', 'Ingénieur procédés',
#        'Chargé de mission commerciale', 'Responsable middle office',
#        'Contrôleur de gestion', 'Chef de secteur commercial',
#        'Responsable méthodes et industrialisation',
#        "Trésorier d'entreprise", 'Chef de chantier', 'Responsable R&D',
#        'Asset manager', 'Géomaticien', "Directeur d'unité de production",
#        'Ingénieur matériaux',
#        'Chef de projet ergonomie et prévention des risques professionnels',
#        'Directeur études, recherche et développement', 'Actuaire',
#        'Supply planner', 'Ingénieur brevets', 'Directeur marketing',
#        'Responsable sécurité informatique', 'Projeteur BIM',
#        'Responsable service après vente', 'Administrateur réseaux',
#        'Banquier conseil M&A', 'Chief Data Officer',
#        "Responsable d'études marketing",
#        "Directeur des systèmes d'information",
#        'Gestionnaire parc automobile et matériel',
#        'Chargé de communication', 'Promoteur des ventes',
#        'Responsable du recrutement', 'Gestionnaire CRM',
#        'Approvisionneur', "Ingénieur d'affaires en ingénierie",
#        'Chercheur en informatique et mathématiques', 'Statisticien',
#        'Responsable de production industrielle',
#        "Conducteur d'opérations", 'Ingénieur poste de travail',
#        'Chargé des affaires réglementaires',
#        'Administrateur de bases de données',
#        'Directeur technique industrielle', 'Ingénieur réseaux',
#        'Responsable maintenance industrielle', 'BIM manager',
#        'Prévisionniste de ventes', 'Responsable logistique',
#        'Directeur de centre de profit', 'Directeur commercial régional',
#        'Métrologue', "Chargé d'études actuarielles",
#        'Commercial en assurances', 'Responsable marketing',
#        'Responsable mécénat', 'Formateur', 'Directeur export',
#        'Ingénieur biologiste', 'Responsable mobilité internationale',
#        'Architecte réseaux', 'Responsable de la diversité',
#        "Chargé d'appels d'offres", 'Assureur qualité', 'Urbaniste',
#        'Designer', 'Responsable ordonnancement et planification',
#        'Gestionnaire back office', 'Auditeur externe',
#        'Ingénieur optique', 'Juriste social', 'Responsable qualité',
#        'Architecte Big Data', 'Rédacteur technique', 'Acheteur projet',
#        "Chargé d'études socio-économiques", 'Administrateur data center',
#        'Chargé de référencement web', 'Contract manager',
#        'Directeur commercial et marketing', 'Ingénieur mise en service',
#        'Consultant logistique', 'Ingénieur plasturgie',
#        'Directeur du développement commercial',
#        'Pharmacien de production', 'Consultant en assurance',
#        "Directeur d'établissement d'accueil de jeunes enfants",
#        "Directeur d'établissement social", 'Chargé de la qualité',
#        'Ingénieur développement BI', 'Généraliste RH',
#        'Ingénieur packaging', "Responsable d'agence commerciale",
#        'Directeur général', 'Consultant finance', 'Commercial immobilier',
#        'Consultant qualité', 'Directeur de start-up', 'Assistant achats',
#        'Gestionnaire de la supply chain',
#        'Conseiller clientèle en banque', 'Ingénieur métallurgiste',
#        'Chargé de relation client', 'Consultant en organisation',
#        'Acheteur public', 'Responsable centre de la relation clients',
#        'Attaché de recherche clinique', 'Auditeur interne',
#        'Responsable MOA', "Consultant en management d'entreprise",
#        'Souscripteur assurance', 'Pricing analyst',
#        'Chargé de conformité', 'Chef de projet marketing', 'Acheteur BTP',
#        'Assistant commercial', "Consultant en management de l'innovation",
#        'Économiste de la construction', 'Risk manager',
#        'Gestionnaire de flux logistiques',
#        "Responsable d'agence immobilière", 'Directeur QHSE',
#        'Community manager',
#        'Responsable technique maintenance et entretien',
#        'Assistant de gestion', 'Directeur de la supply chain',
#        'Assistant de direction', 'Gestionnaire administration des ventes',
#        'Ingénieur biomédical', 'Chargé de formation',
#        "Chef d'équipe commerciale", 'Architecte naval',
#        'Consultant commercial',
#        'Responsable préparation et réception - expédition',
#        'Ingénieur motoriste', 'Conseiller en évolution professionnelle',
#        'Responsable de la gestion des carrières', 'Chef des ventes',
#        'Responsable gestion des stocks', 'Traducteur', 'Retail manager',
#        'Ingénieur traitement du signal',
#        'Délégué à la protection des données', 'Web analyst',
#        'Documentaliste', 'Directeur de la communication',
#        'Analyste crédit', 'Responsable trésorerie',
#        "Chargé d'études marketing", 'Responsable du contrôle de gestion',
#        'Chef de projet en organisation', "Directeur d'association",
#        'Responsable de parc informatique', 'Cadre de santé',
#        'Responsable de restaurant', 'Agent de transport',
#        'Ingénieur développement de composants', 'Cartographe',
#        "Agent général d'assurances", 'Assistant RH', 'Conseiller social',
#        'Ingénieur en biotechnologies', 'Gestionnaire immobilier',
#        "Directeur d'exploitation BTP", 'Assistant social',
#        'Responsable comptable', 'Médecin spécialiste',
#        'Médecin de prévention',
#        "Responsable de laboratoire d'analyses R&D",
#        'Médecin pharmacien biologiste', 'Chef de produit digital',
#        'Homologateur', "Architecte d'intérieur", 'Consultant PLM',
#        'Directeur des ressources humaines',
#        'Responsable développement de franchise', 'Animateur des ventes',
#        'Responsable commercial régional', 'Responsable conditionnement',
#        'Category manager', 'Manager commercial', 'Directeur immobilier',
#        'Responsable SIRH', "Responsable d'hébergement touristique",
#        'Webmaster', 'Directeur comptable', 'Responsable sécurité privée',
#        'Gestionnaire de paie', "Expert d'assurances", 'Ingénieur soudeur',
#        "Directeur d'agence BTP", 'Animateur SAV',
#        'Contrôleur de gestion sociale',
#        'Architecte business intelligence',
#        'Responsable administration du personnel', 'Pharmacien',
#        'Brand content manager', 'Orthophoniste', 'UX designer',
#        'Graphiste', 'Biostatisticien', 'Chef de publicité',
#        'Responsable paie', 'Gestionnaire de copropriété', 'Fiscaliste',
#        'Directeur des achats', 'Traffic manager', 'Chef de cuisine',
#        'Assistant juridique', 'Psychologue', 'Infirmier',
#        'Risk manager bancaire', 'Chargé de facturation clients',
#        'Chargé de recouvrement', 'Ergothérapeute',
#        'Chargé de conformité bancaire', 'Travel manager',
#        "Directeur d'établissement médico-social",
#        'Chargé de mission médico-social', 'Médecin coordonnateur',
#        'Assistant marketing', 'Médecin généraliste',
#        'Social media manager', "Chargé d'affaires dans la formation",
#        'Ingénieur méthode informatique', 'Courtier en assurances',
#        'Directeur de maison de retraite', 'Chef de service médical',
#        'Gestionnaire de sinistres', 'Médecin DIM',
#        'Responsable de magasin', 'Directeur de centre socio-culturel',
#        'Chef de projet événementiel', 'Clerc de notaire',
#        'Pharmacien assurance qualité', 'Chargé de pharmacovigilance',
#        'Délégué médical', 'Merchandiser', 'Expert comptable', 'Éditeur',
#        'Responsable de production informatique',
#        'Directeur de pôle médico-social', 'Responsable juridique',
#        "Responsable d'agence services à la personne",
#        'Chargé de médiation culturelle', 'Responsable rémunérations',
#        'Expert MOA banque', 'Conseiller clientèle en assurances',
#        'Géophysicien', "Directeur d'hôpital", 'Psychologue du travail',
#        'Journaliste', 'Ingénieur formulation', 'acousticien',
#        "Délégué de l'assurance maladie", 'Designer industriel',
#        'Responsable de développement touristique', 'Directeur des soins',
#        'Yield manager', 'Cadre supérieur de santé',
#        'Planneur stratégique', "Gestionnaire de contrats d'assurance",
#        'Web designer', 'Consultant en communication', 'Affréteur',
#        'Contrôleur des coûts'], dtype=object)

# %%
metiers_a_filtrer = ['Data analyst', 'Chief Data Officer', 'Business analyst', 'Data engineer', 'Administrateur data center', 'Ingénieur développement BI', 'Administrateur de bases de données', 'Data scientist', 'Architecte Big Data', 'Web analyst','Chef de projet informatique décisionnelle', 'Ingénieur sécurité informatique', 'Ingénieur test et recettes', 'Architecte infrastructures', 'Responsable sécurité informatique',  'Chef de projet informatique', 'Développeur', 'Ingénieur système', 'Architecte développement', 'Administrateur système', 'Business developer', 'Ingénieur réseaux','Ingénieur informatique embarquée','Ingénieur traitement du signal' , 'Directeur de projets informatiques']

# Filtrer les lignes où la colonne "métier" contient l'un des métiers de la liste
df_filtre = concatenated_df[concatenated_df['metier'].isin(metiers_a_filtrer)]
df_filtre
# Out:
#                              entreprise            type_contrat  \
# 0     MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 1     MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 2                          Marion PINEL                1 \n CDI
# 3                             SESAME IT                2 \n CDI
# 4                              Adsearch                1 \n CDI
# ...                                 ...                     ...
# 9164                      ArcelorMittal                1 \n CDI
# 9170              Thales Avs France Sas                1 \n CDI
# 9171                  AMARIS FRANCE SAS                1 \n CDI
# 9199                  AMARIS FRANCE SAS                1 \n CDI
# 9208               REGION ILE DE FRANCE  1 \n CDD \n de 36 mois
#
#               deparetement       date_publication          date_mise_a_jour  \
# 0     Aix-en-Provence - 13  Publiée le 29/02/2024  Actualisée le 29/02/2024
# 1              Rennes - 35  Publiée le 16/03/2024  Actualisée le 16/03/2024
# 2             Limoges - 87  Publiée le 28/02/2024  Actualisée le 28/02/2024
# 3            Paris 17 - 75  Publiée le 06/02/2024  Actualisée le 11/03/2024
# 4               Rouen - 76  Publiée le 15/03/2024  Actualisée le 15/03/2024
# ...                    ...                    ...                       ...
# 9164        Dunkerque - 59  Publiée le 06/03/2024  Actualisée le 06/03/2024
# 9170         Bordeaux - 33  Publiée le 19/02/2024  Actualisée le 19/02/2024
# 9171     Schiltigheim - 67  Publiée le 19/02/2024  Actualisée le 10/03/2024
# 9199       Strasbourg - 67  Publiée le 04/03/2024  Actualisée le 10/03/2024
# 9208       Saint-Ouen - 93  Publiée le 16/02/2024  Actualisée le 16/02/2024
#
#                             salaire    prise_de_poste  \
# 0            35 - 45 k€ brut annuel  Dès que possible
# 1            35 - 42 k€ brut annuel  Dès que possible
# 2     A partir de 36 k€ brut annuel  Dès que possible
# 3            45 - 55 k€ brut annuel  Dès que possible
# 4            33 - 40 k€ brut annuel  Dès que possible
# ...                             ...               ...
# 9164                     A négocier  Dès que possible
# 9170                     A négocier  Dès que possible
# 9171                     A négocier  Dès que possible
# 9199                     A négocier  Dès que possible
# 9208                     A négocier  Dès que possible
#
#                     experience                                     metier  \
# 0     Aucune expérience exigée                                Développeur
# 1     Aucune expérience exigée                                Développeur
# 2                Minimum 5 ans                                Développeur
# 3                Minimum 5 ans                                Développeur
# 4                Minimum 2 ans                                Développeur
# ...                        ...                                        ...
# 9164              Minimum 1 an                Chef de projet informatique
# 9170              Minimum 1 an                   Architecte développement
# 9171             Minimum 3 ans                          Ingénieur système
# 9199             Minimum 3 ans                                Développeur
# 9208             Minimum 2 ans  Chef de projet informatique décisionnelle
#
#                        statut_du_poste zone_de_deplacement  \
# 0               Cadre du secteur privé  Pas de déplacement
# 1               Cadre du secteur privé  Pas de déplacement
# 2               Cadre du secteur privé  Pas de déplacement
# 3               Cadre du secteur privé  Pas de déplacement
# 4               Cadre du secteur privé  Pas de déplacement
# ...                                ...                 ...
# 9164            Cadre du secteur privé  Pas de déplacement
# 9170            Cadre du secteur privé           Nationale
# 9171            Cadre du secteur privé  Pas de déplacement
# 9199            Cadre du secteur privé  Pas de déplacement
# 9208  Cadre du secteur public / Armées  Pas de déplacement
#
#                                      secteur_d_activite        Teletravail  \
# 0     ACCUEIL OU ACCOMPAGNEMENT SANS HÉBERGEMENT D'A...                NaN
# 1     ACCUEIL OU ACCOMPAGNEMENT SANS HÉBERGEMENT D'A...                NaN
# 2                          FORMATION CONTINUE D'ADULTES   Partiel possible
# 3                            PROGRAMMATION INFORMATIQUE       Non autorisé
# 4     ACTIVITÉS DES AGENCES DE PLACEMENT DE MAIN-D'O...                NaN
# ...                                                 ...                ...
# 9164                                         SIDÉRURGIE                NaN
# 9170                       ACTIVITÉS DES SIÈGES SOCIAUX                NaN
# 9171     CONSEIL EN SYSTÈMES ET LOGICIELS INFORMATIQUES   Partiel possible
# 9199     CONSEIL EN SYSTÈMES ET LOGICIELS INFORMATIQUES                NaN
# 9208                   ADMINISTRATION PUBLIQUE GÉNÉRALE  Ponctuel autorisé
#
#                                        descriptif_poste  \
# 0     En tant que Développeur Web vos fonctions sero...
# 1     Vous intégrez une équipe agile en tant que Dév...
# 2     Nous recherchons un développeur web (H/F) tale...
# 3     Pour venir supporter notre activité en hyper c...
# 4     Notre client est un acteur majeur de l’héberge...
# ...                                                 ...
# 9164  Contexte :\n\n\nRejoindre le Groupe ArcelorMit...
# 9170  QUI SOMMES-NOUS ?\n\nL’activité avionique four...
# 9171  Vous êtes passionné.e par les systèmes informa...
# 9199  Passionné(e) par le développement Java et expe...
# 9208  Mission 1 : Pilotage des projets numériques du...
#
#                                        profil_recherche  \
# 0     De formation supérieure en informatique, vous ...
# 1     Diplômé d'un Bac +5 en informatique minimum, v...
# 2     Connaissances :\nIl/Elle dispose de très bonne...
# 3     Ton profil :\nDe formation Ingénieur ou diplôm...
# 4     VOTRE PROFIL\nVous avez une formation Bac +3 /...
# ...                                                 ...
# 9164  Profil\nVous êtes titulaire d'un BAC +4/5 (Mai...
# 9170   Le profil recherché (compétences et l'expérie...
# 9171   Vos qualifications :\nMinimum Bac+4.\nExpérie...
# 9199   Vos qualifications :\nPour vous épanouir en t...
# 9208  Savoir-faire :\nCapacité à conduire un projet ...
#
#                          langues  \
# 0     ['Aucune langue attendue']
# 1     ['Aucune langue attendue']
# 2        ['Français', 'Anglais']
# 3     ['Aucune langue attendue']
# 4     ['Aucune langue attendue']
# ...                          ...
# 9164                 ['Anglais']
# 9170  ['Aucune langue attendue']
# 9171  ['Aucune langue attendue']
# 9199  ['Aucune langue attendue']
# 9208  ['Aucune langue attendue']
#
#                                             savoir_etre  \
# 0     ['Autonomie', "Capacité d'analyse", 'Capacité ...
# 1     ['Curiosité', "Esprit d'équipe", 'Force de pro...
# 2     ['Autonomie', 'Créativité', "Esprit d'équipe",...
# 3     ['Autonomie', 'Capacité à travailler en mode p...
# 4     ['Autonomie', 'Proactivité', "Sens de l'engage...
# ...                                                 ...
# 9164  ['Capacité à travailler en mode projet', "Capa...
# 9170  ['Capacité de conseil', "Sens de l'organisation"]
# 9171  ['Capacité à résoudre des problèmes', 'Capacit...
# 9199  ['Capacité à travailler en mode projet', "Capa...
# 9208  ["Capacité d'adaptation", 'Capacité de communi...
#
#                                            savoir_faire  \
# 0     ['Application Web', 'Développement web', 'Info...
# 1     ['Développement web', 'CakePHP', 'CQRS', 'DDD'...
# 2     ['Angular JS', 'Apache', 'Application Web', 'A...
# 3     ['Base de données', 'Interface de programmatio...
# 4     ['Automatisme', 'Cappuccino', 'Économie', 'Fra...
# ...                                                 ...
# 9164  ['AMF', 'Benchmarking', 'Business Management',...
# 9170  ['Génie informatique', 'GIT', 'Jira', 'Aérospa...
# 9171  ['Administration système et réseau', 'Ansible'...
# 9199  ['Apache Maven', 'Amélioration continue', 'Aut...
# 9208  ['Formation continue et professionnelle', 'QS'...
#
#                                   descriptif_entreprise
# 0     Notre client est un éditeur de logiciels dans ...
# 1     Notre client, éditeur de logiciel dynamique, r...
# 2     L'Office International de l'Eau (OiEau, www.oi...
# 3     Spécialiste de l'anticipation des menaces, Ses...
# 4     Adsearch vous propose des milliers d''opportun...
# ...                                                 ...
# 9164  Rejoindre le Groupe ArcelorMittal c’est partic...
# 9170  Chez Thales, nous sommes fiers de travailler e...
# 9171  Amaris Consulting est une société indépendante...
# 9199  Amaris Consulting est une société indépendante...
# 9208  Employeur de premier plan, la Région Ile-de-Fr...
#
# [5494 rows x 19 columns]
