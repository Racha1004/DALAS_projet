# %%
import pandas as pd

# %%
df1 = pd.read_csv("Scrapped_Data/ancienne_data/Apec_data_total.csv")  
df1
# Out:
#                              entreprise type_contrat  \
# 0                               AI&Data     1 \n CDI
# 1                            VR CONSEIL     1 \n CDI
# 2                                 MACIF     1 \n CDI
# 3                                MYDRAL     1 \n CDI
# 4     MICHAEL PAGE INTERNATIONAL FRANCE     1 \n CDI
# ...                                 ...          ...
# 996     Soft Computing - Epsilon France     1 \n CDI
# 997                 Segula Technologies     1 \n CDI
# 998                Cabinet 6eme Sens RH     1 \n CDI
# 999                             POLARYS     1 \n CDI
# 1000          MINSART-KREMER & Partners     2 \n CDI
#
#                    deparetement       date_publication  \
# 0     Boulogne-Billancourt - 92  Publiée le 01/02/2024
# 1                 Paris 09 - 75  Publiée le 14/12/2023
# 2                    Niort - 79  Publiée le 07/02/2024
# 3                 Paris 02 - 75  Publiée le 05/02/2024
# ...

# %%
df2 = pd.read_csv("Scrapped_Data/Data_Apec_data/Apec_data_total.csv")
df2
# Out:
#                                  entreprise            type_contrat  \
# 0                      ECM (Direction Nord)                1 \n CDI
# 1                                 SP SEARCH                1 \n CDI
# 2                                 SP SEARCH                1 \n CDI
# 3                                 SP SEARCH                1 \n CDI
# 4                                 SP SEARCH                1 \n CDI
# ...                                     ...                     ...
# 6130     DIRECTION GENERALE DES ENTREPRISES  1 \n CDD \n de 36 mois
# 6131                             SEMAPHORES                1 \n CDI
# 6132  INVIVO RETAIL PRODUCTION MARCHANDISES                1 \n CDI
# 6133                               SIBYLONE                1 \n CDI
# 6134                                 PARLYM                1 \n CDI
#
#              deparetement       date_publication          date_mise_a_jour  \
# ...

# %%
df3 = pd.read_csv("Scrapped_Data/Data_Apec_cyberSec/Apec_data_total.csv")
df3
# Out:
#                              entreprise                          type_contrat  \
# 0     MICHAEL PAGE INTERNATIONAL FRANCE                              1 \n CDI
# 1                              Adsearch                              1 \n CDI
# 2                         JEROME ALEPSA                              1 \n CDI
# 3            Office National des Forêts                              1 \n CDI
# 4                              Expectra  1 \n Mission d'intérim \n de 18 mois
# ...                                 ...                                   ...
# 2521                              Apgar                              1 \n CDI
# 2522          Solidarités International                              1 \n CDI
# 2523                            ARTELIA                              1 \n CDI
# 2524               GMBA Walter Allinial                              1 \n CDI
# 2525            DR PARIS IDF CENTRE-EST                1 \n CDD \n de 24 mois
#
# ...

# %%
df = pd.concat([df1,df2 , df3] , ignore_index=True)
df = df.drop_duplicates()
df.reset_index(drop=True, inplace=True)
df
# Out:
#                              entreprise            type_contrat  \
# 0                               AI&Data                1 \n CDI
# 1                            VR CONSEIL                1 \n CDI
# 2                                 MACIF                1 \n CDI
# 3                                MYDRAL                1 \n CDI
# 4     MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# ...                                 ...                     ...
# 9207                    Q ENERGY France                1 \n CDI
# 9208               REGION ILE DE FRANCE  1 \n CDD \n de 36 mois
# 9209                            ARTELIA                1 \n CDI
# 9210               GMBA Walter Allinial                1 \n CDI
# 9211            DR PARIS IDF CENTRE-EST  1 \n CDD \n de 24 mois
#
#                    deparetement       date_publication  \
# 0     Boulogne-Billancourt - 92  Publiée le 01/02/2024
# 1                 Paris 09 - 75  Publiée le 14/12/2023
# ...

# %%
df.to_csv(f'Scrapped_Data/Merge_data_cybSec_ancienne/Apec_data_total_merged.csv', index=False)
