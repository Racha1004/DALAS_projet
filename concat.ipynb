# %%
import pandas as pd

# %%
df1 = pd.read_csv("Scrapped_Data/Data_Apec_data/Apec_data_1.csv")  
df1
# Out:
#                            entreprise            type_contrat  \
# 0                ECM (Direction Nord)                1 \n CDI
# 1                           SP SEARCH                1 \n CDI
# 2                           SP SEARCH                1 \n CDI
# 3                           SP SEARCH                1 \n CDI
# 4                           SP SEARCH                1 \n CDI
# 5                           SP SEARCH                1 \n CDI
# 6                           SP SEARCH                1 \n CDI
# 7                           SP SEARCH                1 \n CDI
# 8                           SP SEARCH                1 \n CDI
# 9                           SP SEARCH                1 \n CDI
# 10                          SP SEARCH                1 \n CDI
# 11                          SP SEARCH                1 \n CDI
# 12                          SP SEARCH                1 \n CDI
# 13                          SP SEARCH                1 \n CDI
# ...

# %%
df2 = pd.read_csv("Scrapped_Data/Data_Apec_data/Apec_data_2.csv")
df2
# Out:
#                             entreprise  \
# 0    MICHAEL PAGE INTERNATIONAL FRANCE
# 1    MICHAEL PAGE INTERNATIONAL FRANCE
# 2    MICHAEL PAGE INTERNATIONAL FRANCE
# 3    MICHAEL PAGE INTERNATIONAL FRANCE
# 4    MICHAEL PAGE INTERNATIONAL FRANCE
# ..                                 ...
# 445                           ALEXY RH
# 446            SPIE BUILDING SOLUTIONS
# 447                   Innova Solutions
# 448                     Groupe ECOCERT
# 449            Safran Aircraft Engines
#
#                                  type_contrat          deparetement  \
# 0                                    1 \n CDI         Paris 08 - 75
# 1                                    1 \n CDI       Saint-Ouen - 93
# 2                                    1 \n CDI       Courbevoie - 92
# 3                                    1 \n CDI   Ivry-sur-Seine - 94
# 4                                    1 \n CDI       Courbevoie - 92
# ..                                        ...                   ...
# ...

# %%
df3 = pd.read_csv("Scrapped_Data/Data_Apec_data/Apec_data_3.csv")
df3
# Out:
#                                  entreprise  \
# 0                         DO IT - PLATINIUM
# 1                       Orange Cyberdefense
# 2                                     MILEE
# 3                              SARL ARTEMYS
# 4                           TALAN CORPORATE
# ...                                     ...
# 5648     DIRECTION GENERALE DES ENTREPRISES
# 5649                             SEMAPHORES
# 5650  INVIVO RETAIL PRODUCTION MARCHANDISES
# 5651                               SIBYLONE
# 5652                                 PARLYM
#
#                                            type_contrat          deparetement  \
# 0                                              4 \n CDI  Aix-en-Provence - 13
# 1     1 \n CDD et Alternance – Contrat d'apprentissa...         Toulouse - 31
# 2                                              1 \n CDI           Amiens - 80
# 3                                              1 \n CDI            Rouen - 76
# ...

# %%
df = pd.concat([df1,df2 , df3] , ignore_index=True)
df
# Out:
#                                  entreprise            type_contrat  \
# 0                      ECM (Direction Nord)                1 \n CDI
# 1                                 SP SEARCH                1 \n CDI
# 2                                 SP SEARCH                1 \n CDI
# 3                                 SP SEARCH                1 \n CDI
# 4                                 SP SEARCH                1 \n CDI
# ...                                     ...                     ...
# 6130     DIRECTION GENERALE DES ENTREPRISES  1 \n CDD \n de 36 mois
# 6131                             SEMAPHORES                1 \n CDI
# 6132  INVIVO RETAIL PRODUCTION MARCHANDISES                1 \n CDI
# 6133                               SIBYLONE                1 \n CDI
# 6134                                 PARLYM                1 \n CDI
#
#              deparetement       date_publication          date_mise_a_jour  \
# ...

# %%
df.to_csv(f'Scrapped_Data/Data_Apec/Apec_data_total.csv', index=False)
