# %%
import pandas as pd

# %%
df1 = pd.read_csv("Scrapped_Data/Data_Apec/Apec_data_1.csv")  
df1
# Out:
#            entreprise type_contrat               deparetement  \
# 0             AI&Data     1 \n CDI  Boulogne-Billancourt - 92
# 1              MYDRAL     1 \n CDI              Paris 02 - 75
# 2            LKK DATA     1 \n CDI       Rueil-Malmaison - 92
# 3           CircularX     1 \n CDI              Gentilly - 94
# 4           CircularX     1 \n CDI                Nantes - 44
# ..                ...          ...                        ...
# 539   ORANGE BUSINESS     1 \n CDI              Nanterre - 92
# 540             O2MAX     1 \n CDI               Lyon 01 - 69
# 541  (Confidentielle)     2 \n CDI                 Paris - 75
# 542          ISOSKELE     1 \n CDI             Montrouge - 92
# 543          ISOSKELE     1 \n CDI             Montrouge - 92
#
#           date_publication          date_mise_a_jour  \
# 0    Publiée le 01/02/2024  Actualisée le 01/02/2024
# 1    Publiée le 05/02/2024  Actualisée le 05/02/2024
# 2    Publiée le 15/02/2024  Actualisée le 15/02/2024
# ...

# %%
df1.groupby('deparetement').count().head(20)
pd.DataFrame(df1[df1['deparetement'].str.contains('Paris')].groupby('deparetement').size().sort_values(ascending=False)).head(20)

# count_data = df1[df1['entreprise'].str.contains('scien')]
# count_data
# Out:
#                 0
# deparetement
# Paris 01 - 75  29
# Paris 02 - 75  21
# Paris 15 - 75  20
# Paris 09 - 75  18
# Paris 08 - 75  18
# Paris 11 - 75   9
# Paris 03 - 75   6
# Paris 06 - 75   5
# Paris 13 - 75   4
# Paris 17 - 75   4
# Paris 16 - 75   4
# Paris 20 - 75   2
# Paris 05 - 75   2
# Paris 12 - 75   1
# Paris 07 - 75   1
# Paris 19 - 75   1
# Paris - 75      1

# %%
df2 = pd.read_csv("Scrapped_Data/Data_Apec/Apec_data_2.csv")
df2
# Out:
#             entreprise           type_contrat         deparetement  \
# 0              POLARYS               5 \n CDI        Colombes - 92
# 1       EPSILON France  1 \n CDD \n de 5 mois        Paris 11 - 75
# 2              Opensee               1 \n CDI        Paris 17 - 75
# 3     (Confidentielle)               2 \n CDI           Paris - 75
# 4               ITIZEN               1 \n CDI        Paris 01 - 75
# ...                ...                    ...                  ...
# 1425        Dogfinance               1 \n CDI  Maisons-Alfort - 94
# 1426        Dogfinance               1 \n CDI  Maisons-Alfort - 94
# 1427        Dogfinance               1 \n CDI  Maisons-Alfort - 94
# 1428        Dogfinance               1 \n CDI  Maisons-Alfort - 94
# 1429             OP3FT               1 \n CDI        Paris 16 - 75
#
#            date_publication          date_mise_a_jour  \
# 0     Publiée le 30/01/2024  Actualisée le 30/01/2024
# ...

# %%
df = pd.concat([df1,df2] , ignore_index=True)
df
# Out:
#       entreprise type_contrat               deparetement  \
# 0        AI&Data     1 \n CDI  Boulogne-Billancourt - 92
# 1         MYDRAL     1 \n CDI              Paris 02 - 75
# 2       LKK DATA     1 \n CDI       Rueil-Malmaison - 92
# 3      CircularX     1 \n CDI              Gentilly - 94
# 4      CircularX     1 \n CDI                Nantes - 44
# ...          ...          ...                        ...
# 1969  Dogfinance     1 \n CDI        Maisons-Alfort - 94
# 1970  Dogfinance     1 \n CDI        Maisons-Alfort - 94
# 1971  Dogfinance     1 \n CDI        Maisons-Alfort - 94
# 1972  Dogfinance     1 \n CDI        Maisons-Alfort - 94
# 1973       OP3FT     1 \n CDI              Paris 16 - 75
#
#            date_publication          date_mise_a_jour                 salaire  \
# 0     Publiée le 01/02/2024  Actualisée le 01/02/2024              A négocier
# 1     Publiée le 05/02/2024  Actualisée le 05/02/2024  40 - 45 k€ brut annuel
# ...

# %%
df.to_csv(f'Scrapped_Data/Data_Apec/Apec_data_total.csv', index=False)
