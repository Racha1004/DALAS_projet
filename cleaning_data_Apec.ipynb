# %% [markdown]
# # Imporation des bibliothéques

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Chargement des données

# %%
df = pd.read_csv("Scrapped_Data/Merge_data_cybSec_ancienne/Apec_data_total_merged_filred.csv")
df
# Out:
#                              entreprise            type_contrat  \
# 0                               AI&Data                1 \n CDI
# 1                            VR CONSEIL                1 \n CDI
# 2                                 MACIF                1 \n CDI
# 3                                MYDRAL                1 \n CDI
# 4     MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# ...                                 ...                     ...
# 3711                             MONEXT                1 \n CDI
# 3712                          CDISCOUNT                1 \n CDI
# 3713                  AMARIS FRANCE SAS                1 \n CDI
# 3714               REGION ILE DE FRANCE  1 \n CDD \n de 36 mois
# 3715            DR PARIS IDF CENTRE-EST  1 \n CDD \n de 24 mois
#
#                    deparetement       date_publication  \
# 0     Boulogne-Billancourt - 92  Publiée le 01/02/2024
# 1                 Paris 09 - 75  Publiée le 14/12/2023
# 2                    Niort - 79  Publiée le 07/02/2024
# 3                 Paris 02 - 75  Publiée le 05/02/2024
# 4                   Rennes - 35  Publiée le 27/01/2024
# ...                         ...                    ...
# 3711       Aix-en-Provence - 13  Publiée le 08/03/2024
# 3712              Bordeaux - 33  Publiée le 05/03/2024
# 3713            Strasbourg - 67  Publiée le 04/03/2024
# 3714            Saint-Ouen - 93  Publiée le 16/02/2024
# 3715              Paris 15 - 75  Publiée le 26/01/2024
#
#               date_mise_a_jour                        salaire  \
# 0     Actualisée le 01/02/2024                     A négocier
# 1     Actualisée le 15/01/2024         45 - 75 k€ brut annuel
# 2     Actualisée le 07/02/2024                     A négocier
# 3     Actualisée le 05/02/2024         40 - 45 k€ brut annuel
# 4     Actualisée le 27/01/2024         45 - 55 k€ brut annuel
# ...                        ...                            ...
# 3711  Actualisée le 08/03/2024                     A négocier
# 3712  Actualisée le 05/03/2024                     A négocier
# 3713  Actualisée le 10/03/2024                     A négocier
# 3714  Actualisée le 16/02/2024                     A négocier
# 3715  Actualisée le 11/03/2024  A partir de 35 k€ brut annuel
#
#         prise_de_poste                          experience  \
# 0     Dès que possible                       Minimum 2 ans
# 1     Dès que possible                       Minimum 5 ans
# 2     Dès que possible                       Minimum 2 ans
# 3     Dès que possible                       Minimum 2 ans
# 4     Dès que possible            Aucune expérience exigée
# ...                ...                                 ...
# 3711  Dès que possible  Tous niveaux d'expérience acceptés
# 3712  Dès que possible                       Minimum 5 ans
# 3713  Dès que possible                       Minimum 3 ans
# 3714  Dès que possible                       Minimum 2 ans
# 3715  Dès que possible  Tous niveaux d'expérience acceptés
#
#                                          metier  \
# 0                                  Data analyst
# 1                                 Data engineer
# 2                                  Data analyst
# 3                                  Data analyst
# 4                                  Data analyst
# ...                                         ...
# 3711                 Ingénieur test et recettes
# 3712                                Développeur
# 3713                                Développeur
# 3714  Chef de projet informatique décisionnelle
# 3715                   Architecte développement
#
#                        statut_du_poste zone_de_deplacement  \
# 0               Cadre du secteur privé           Nationale
# 1               Cadre du secteur privé  Pas de déplacement
# 2               Cadre du secteur privé  Pas de déplacement
# 3               Cadre du secteur privé           Régionale
# 4               Cadre du secteur privé  Pas de déplacement
# ...                                ...                 ...
# 3711            Cadre du secteur privé  Pas de déplacement
# 3712            Cadre du secteur privé  Pas de déplacement
# 3713            Cadre du secteur privé  Pas de déplacement
# 3714  Cadre du secteur public / Armées  Pas de déplacement
# 3715  Cadre du secteur public / Armées  Pas de déplacement
#
#                                      secteur_d_activite        Teletravail  \
# 0     TRAITEMENT DE DONNÉES, HÉBERGEMENT ET ACTIVITÉ...                NaN
# 1     CONSEIL POUR LES AFFAIRES ET AUTRES CONSEILS D...   Partiel possible
# 2                                     AUTRES ASSURANCES   Partiel possible
# 3        CONSEIL EN SYSTÈMES ET LOGICIELS INFORMATIQUES  Ponctuel autorisé
# 4     FABRICATION DE PRODUITS DE CONSOMMATION COURAN...                NaN
# ...                                                 ...                ...
# 3711  AUTRES ACTIVITÉS AUXILIAIRES DE SERVICES FINAN...   Partiel possible
# 3712             VENTE À DISTANCE SUR CATALOGUE GÉNÉRAL                NaN
# 3713     CONSEIL EN SYSTÈMES ET LOGICIELS INFORMATIQUES                NaN
# 3714                   ADMINISTRATION PUBLIQUE GÉNÉRALE  Ponctuel autorisé
# 3715  RECHERCHE-DÉVELOPPEMENT EN AUTRES SCIENCES PHY...   Partiel possible
#
#                                        descriptif_poste  \
# 0     AI&Data  recherche aujourd'hui des Data Analys...
# 1     Auprès d'un de nos clients dans l'univers de l...
# 2     Vous avez envie de donner un nouvel élan à vot...
# 3     Les tâches proposées ?\nSous la supervision du...
# 4     Vos responsabilités comme Data Analyst :\nLa c...
# ...                                                 ...
# 3711  Contexte\nAu sein du Pôle Acquisition, l’équip...
# 3712  Rejoignez Peaksys, venez faire du hors norme v...
# 3713  Passionné(e) par le développement Java et expe...
# 3714  Mission 1 : Pilotage des projets numériques du...
# 3715  Dans le cadre de France 2030, qui promeut le d...
#
#                                        profil_recherche  \
# 0     De formation supérieure en statistiques et mat...
# 1     De formation supérieure Bac+ 4/5, vous justifi...
# 2     Vous possédez un BAC +5 avec une spécialisatio...
# 3     Le profil recherché ?\nPassionné de la Data et...
# 4     De formation supérieure en statistiques, infor...
# ...                                                 ...
# 3711  Profil recherché\nCe que tu peux apporter :\nI...
# 3712  Nous recherchons des collaborateurs ayant une ...
# 3713   Vos qualifications :\nPour vous épanouir en t...
# 3714  Savoir-faire :\nCapacité à conduire un projet ...
# 3715  Connaissances\n ·         Bonnes connaissances...
#
#                          langues  \
# 0     ['Aucune langue attendue']
# 1     ['Aucune langue attendue']
# 2     ['Aucune langue attendue']
# 3     ['Aucune langue attendue']
# 4     ['Aucune langue attendue']
# ...                          ...
# 3711                 ['Anglais']
# 3712  ['Aucune langue attendue']
# 3713  ['Aucune langue attendue']
# 3714  ['Aucune langue attendue']
# 3715  ['Aucune langue attendue']
#
#                                             savoir_etre  \
# 0     ['Capacité à prendre des décisions', "Capacité...
# 1                         ['Aucun savoir-être attendu']
# 2     ['Autonomie', "Capacité d'adaptation", "Capaci...
# 3     ['Autonomie', "Esprit d'équipe", 'Passionne', ...
# 4                            ['Autonomie', 'Pédagogie']
# ...                                                 ...
# 3711  ["Capacité d'adaptation", 'Curiosité', "Esprit...
# 3712  ['Ambition', "Capacité d'adaptation", 'Capacit...
# 3713  ['Capacité à travailler en mode projet', "Capa...
# 3714  ["Capacité d'adaptation", 'Capacité de communi...
# 3715                      ['Aucun savoir-être attendu']
#
#                                            savoir_faire  \
# 0     ['Algorithme', 'Amazon Web Services', 'Base de...
# 1                        ['Aucun savoir-faire attendu']
# 2     ['Langage R', 'Python', 'Spark', 'SQL', 'Trait...
# 3     ['Analyse de données', 'Data Visualisation', '...
# 4     ['Analyse de données', 'Analyse des besoins', ...
# ...                                                 ...
# 3711  ['Test fonctionnel', 'Accompagnement du client...
# 3712  ['Docker', 'GIT', 'Interface de programmation ...
# 3713  ['Apache Maven', 'Amélioration continue', 'Aut...
# 3714  ['Formation continue et professionnelle', 'QS'...
# 3715                     ['Aucun savoir-faire attendu']
#
#                                   descriptif_entreprise
# 0     AI&Data est une Agence Data sur trois domaines...
# 1     Créée en 2004, VR Conseil est une ESN spéciali...
# 2     Entreprise de l'Économie Sociale, la Macif n'a...
# 3     Mydral  est une entreprise qui aide ses client...
# 4     Notre client, client final dans le secteur ind...
# ...                                                 ...
# 3711  MONEXT est un acteur majeur du paiement en Fra...
# 3712  Chez Peaksys, filiale Tech de Cdiscount, nous ...
# 3713  Amaris Consulting est une société indépendante...
# 3714  Employeur de premier plan, la Région Ile-de-Fr...
# 3715  L' Inserm est le seul organisme public françai...
#
# [3716 rows x 19 columns]

# %% [markdown]
# # Diviser la colonne type_contrat en 2 colonnes  (type_contrat et nombre_posts)

# %%
type_contrat_splitted = df['type_contrat'].str.split('\n', expand=True)
df['nombre_posts'] = type_contrat_splitted[0]
df['type_contrat'] = type_contrat_splitted[1]
df['duree'] = type_contrat_splitted[2]
df
# Out:
#                              entreprise type_contrat  \
# 0                               AI&Data          CDI
# 1                            VR CONSEIL          CDI
# 2                                 MACIF          CDI
# 3                                MYDRAL          CDI
# 4     MICHAEL PAGE INTERNATIONAL FRANCE          CDI
# ...                                 ...          ...
# 3711                             MONEXT          CDI
# 3712                          CDISCOUNT          CDI
# 3713                  AMARIS FRANCE SAS          CDI
# 3714               REGION ILE DE FRANCE         CDD
# 3715            DR PARIS IDF CENTRE-EST         CDD
#
#                    deparetement       date_publication  \
# 0     Boulogne-Billancourt - 92  Publiée le 01/02/2024
# 1                 Paris 09 - 75  Publiée le 14/12/2023
# 2                    Niort - 79  Publiée le 07/02/2024
# 3                 Paris 02 - 75  Publiée le 05/02/2024
# 4                   Rennes - 35  Publiée le 27/01/2024
# ...                         ...                    ...
# 3711       Aix-en-Provence - 13  Publiée le 08/03/2024
# 3712              Bordeaux - 33  Publiée le 05/03/2024
# 3713            Strasbourg - 67  Publiée le 04/03/2024
# 3714            Saint-Ouen - 93  Publiée le 16/02/2024
# 3715              Paris 15 - 75  Publiée le 26/01/2024
#
#               date_mise_a_jour                        salaire  \
# 0     Actualisée le 01/02/2024                     A négocier
# 1     Actualisée le 15/01/2024         45 - 75 k€ brut annuel
# 2     Actualisée le 07/02/2024                     A négocier
# 3     Actualisée le 05/02/2024         40 - 45 k€ brut annuel
# 4     Actualisée le 27/01/2024         45 - 55 k€ brut annuel
# ...                        ...                            ...
# 3711  Actualisée le 08/03/2024                     A négocier
# 3712  Actualisée le 05/03/2024                     A négocier
# 3713  Actualisée le 10/03/2024                     A négocier
# 3714  Actualisée le 16/02/2024                     A négocier
# 3715  Actualisée le 11/03/2024  A partir de 35 k€ brut annuel
#
#         prise_de_poste                          experience  \
# 0     Dès que possible                       Minimum 2 ans
# 1     Dès que possible                       Minimum 5 ans
# 2     Dès que possible                       Minimum 2 ans
# 3     Dès que possible                       Minimum 2 ans
# 4     Dès que possible            Aucune expérience exigée
# ...                ...                                 ...
# 3711  Dès que possible  Tous niveaux d'expérience acceptés
# 3712  Dès que possible                       Minimum 5 ans
# 3713  Dès que possible                       Minimum 3 ans
# 3714  Dès que possible                       Minimum 2 ans
# 3715  Dès que possible  Tous niveaux d'expérience acceptés
#
#                                          metier  \
# 0                                  Data analyst
# 1                                 Data engineer
# 2                                  Data analyst
# 3                                  Data analyst
# 4                                  Data analyst
# ...                                         ...
# 3711                 Ingénieur test et recettes
# 3712                                Développeur
# 3713                                Développeur
# 3714  Chef de projet informatique décisionnelle
# 3715                   Architecte développement
#
#                        statut_du_poste  ...  \
# 0               Cadre du secteur privé  ...
# 1               Cadre du secteur privé  ...
# 2               Cadre du secteur privé  ...
# 3               Cadre du secteur privé  ...
# 4               Cadre du secteur privé  ...
# ...                                ...  ...
# 3711            Cadre du secteur privé  ...
# 3712            Cadre du secteur privé  ...
# 3713            Cadre du secteur privé  ...
# 3714  Cadre du secteur public / Armées  ...
# 3715  Cadre du secteur public / Armées  ...
#
#                                      secteur_d_activite        Teletravail  \
# 0     TRAITEMENT DE DONNÉES, HÉBERGEMENT ET ACTIVITÉ...                NaN
# 1     CONSEIL POUR LES AFFAIRES ET AUTRES CONSEILS D...   Partiel possible
# 2                                     AUTRES ASSURANCES   Partiel possible
# 3        CONSEIL EN SYSTÈMES ET LOGICIELS INFORMATIQUES  Ponctuel autorisé
# 4     FABRICATION DE PRODUITS DE CONSOMMATION COURAN...                NaN
# ...                                                 ...                ...
# 3711  AUTRES ACTIVITÉS AUXILIAIRES DE SERVICES FINAN...   Partiel possible
# 3712             VENTE À DISTANCE SUR CATALOGUE GÉNÉRAL                NaN
# 3713     CONSEIL EN SYSTÈMES ET LOGICIELS INFORMATIQUES                NaN
# 3714                   ADMINISTRATION PUBLIQUE GÉNÉRALE  Ponctuel autorisé
# 3715  RECHERCHE-DÉVELOPPEMENT EN AUTRES SCIENCES PHY...   Partiel possible
#
#                                        descriptif_poste  \
# 0     AI&Data  recherche aujourd'hui des Data Analys...
# 1     Auprès d'un de nos clients dans l'univers de l...
# 2     Vous avez envie de donner un nouvel élan à vot...
# 3     Les tâches proposées ?\nSous la supervision du...
# 4     Vos responsabilités comme Data Analyst :\nLa c...
# ...                                                 ...
# 3711  Contexte\nAu sein du Pôle Acquisition, l’équip...
# 3712  Rejoignez Peaksys, venez faire du hors norme v...
# 3713  Passionné(e) par le développement Java et expe...
# 3714  Mission 1 : Pilotage des projets numériques du...
# 3715  Dans le cadre de France 2030, qui promeut le d...
#
#                                        profil_recherche  \
# 0     De formation supérieure en statistiques et mat...
# 1     De formation supérieure Bac+ 4/5, vous justifi...
# 2     Vous possédez un BAC +5 avec une spécialisatio...
# 3     Le profil recherché ?\nPassionné de la Data et...
# 4     De formation supérieure en statistiques, infor...
# ...                                                 ...
# 3711  Profil recherché\nCe que tu peux apporter :\nI...
# 3712  Nous recherchons des collaborateurs ayant une ...
# 3713   Vos qualifications :\nPour vous épanouir en t...
# 3714  Savoir-faire :\nCapacité à conduire un projet ...
# 3715  Connaissances\n ·         Bonnes connaissances...
#
#                          langues  \
# 0     ['Aucune langue attendue']
# 1     ['Aucune langue attendue']
# 2     ['Aucune langue attendue']
# 3     ['Aucune langue attendue']
# 4     ['Aucune langue attendue']
# ...                          ...
# 3711                 ['Anglais']
# 3712  ['Aucune langue attendue']
# 3713  ['Aucune langue attendue']
# 3714  ['Aucune langue attendue']
# 3715  ['Aucune langue attendue']
#
#                                             savoir_etre  \
# 0     ['Capacité à prendre des décisions', "Capacité...
# 1                         ['Aucun savoir-être attendu']
# 2     ['Autonomie', "Capacité d'adaptation", "Capaci...
# 3     ['Autonomie', "Esprit d'équipe", 'Passionne', ...
# 4                            ['Autonomie', 'Pédagogie']
# ...                                                 ...
# 3711  ["Capacité d'adaptation", 'Curiosité', "Esprit...
# 3712  ['Ambition', "Capacité d'adaptation", 'Capacit...
# 3713  ['Capacité à travailler en mode projet', "Capa...
# 3714  ["Capacité d'adaptation", 'Capacité de communi...
# 3715                      ['Aucun savoir-être attendu']
#
#                                            savoir_faire  \
# 0     ['Algorithme', 'Amazon Web Services', 'Base de...
# 1                        ['Aucun savoir-faire attendu']
# 2     ['Langage R', 'Python', 'Spark', 'SQL', 'Trait...
# 3     ['Analyse de données', 'Data Visualisation', '...
# 4     ['Analyse de données', 'Analyse des besoins', ...
# ...                                                 ...
# 3711  ['Test fonctionnel', 'Accompagnement du client...
# 3712  ['Docker', 'GIT', 'Interface de programmation ...
# 3713  ['Apache Maven', 'Amélioration continue', 'Aut...
# 3714  ['Formation continue et professionnelle', 'QS'...
# 3715                     ['Aucun savoir-faire attendu']
#
#                                   descriptif_entreprise nombre_posts  \
# 0     AI&Data est une Agence Data sur trois domaines...           1
# 1     Créée en 2004, VR Conseil est une ESN spéciali...           1
# 2     Entreprise de l'Économie Sociale, la Macif n'a...           1
# 3     Mydral  est une entreprise qui aide ses client...           1
# 4     Notre client, client final dans le secteur ind...           1
# ...                                                 ...          ...
# 3711  MONEXT est un acteur majeur du paiement en Fra...           1
# 3712  Chez Peaksys, filiale Tech de Cdiscount, nous ...           1
# 3713  Amaris Consulting est une société indépendante...           1
# 3714  Employeur de premier plan, la Région Ile-de-Fr...           1
# 3715  L' Inserm est le seul organisme public françai...           1
#
#             duree
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 3711         None
# 3712         None
# 3713         None
# 3714   de 36 mois
# 3715   de 24 mois
#
# [3716 rows x 21 columns]

# %%
df['type_contrat'] = df['type_contrat'].str.strip().str.replace('Missions', 'Mission')
df['type_contrat'] .unique()
# Out:
# array(['CDI', "Mission d'intérim", 'CDD',
#        "CDD et Alternance – Contrat d'apprentissage",
#        "CDI et Alternance – Contrat d'apprentissage",
#        'CDD et Alternance – Contrat de professionnalisation'],
#       dtype=object)

# %% [markdown]
# # Convertir les colonnes date_publication et date_mise_a_jour en DATE

# %%
df['date_publication'] = df['date_publication'].str.split(' ', expand=True)[2]
df['date_publication'] = pd.to_datetime(df['date_publication'], dayfirst=True)

df['date_mise_a_jour'] = df['date_mise_a_jour'].str.split(' ', expand=True)[2]
df['date_mise_a_jour'] = pd.to_datetime(df['date_mise_a_jour'], dayfirst=True)
df
# Out:
#                              entreprise type_contrat  \
# 0                               AI&Data          CDI
# 1                            VR CONSEIL          CDI
# 2                                 MACIF          CDI
# 3                                MYDRAL          CDI
# 4     MICHAEL PAGE INTERNATIONAL FRANCE          CDI
# ...                                 ...          ...
# 3711                             MONEXT          CDI
# 3712                          CDISCOUNT          CDI
# 3713                  AMARIS FRANCE SAS          CDI
# 3714               REGION ILE DE FRANCE          CDD
# 3715            DR PARIS IDF CENTRE-EST          CDD
#
#                    deparetement date_publication date_mise_a_jour  \
# 0     Boulogne-Billancourt - 92       2024-02-01       2024-02-01
# 1                 Paris 09 - 75       2023-12-14       2024-01-15
# 2                    Niort - 79       2024-02-07       2024-02-07
# 3                 Paris 02 - 75       2024-02-05       2024-02-05
# 4                   Rennes - 35       2024-01-27       2024-01-27
# ...                         ...              ...              ...
# 3711       Aix-en-Provence - 13       2024-03-08       2024-03-08
# 3712              Bordeaux - 33       2024-03-05       2024-03-05
# 3713            Strasbourg - 67       2024-03-04       2024-03-10
# 3714            Saint-Ouen - 93       2024-02-16       2024-02-16
# 3715              Paris 15 - 75       2024-01-26       2024-03-11
#
#                             salaire    prise_de_poste  \
# 0                        A négocier  Dès que possible
# 1            45 - 75 k€ brut annuel  Dès que possible
# 2                        A négocier  Dès que possible
# 3            40 - 45 k€ brut annuel  Dès que possible
# 4            45 - 55 k€ brut annuel  Dès que possible
# ...                             ...               ...
# 3711                     A négocier  Dès que possible
# 3712                     A négocier  Dès que possible
# 3713                     A négocier  Dès que possible
# 3714                     A négocier  Dès que possible
# 3715  A partir de 35 k€ brut annuel  Dès que possible
#
#                               experience  \
# 0                          Minimum 2 ans
# 1                          Minimum 5 ans
# 2                          Minimum 2 ans
# 3                          Minimum 2 ans
# 4               Aucune expérience exigée
# ...                                  ...
# 3711  Tous niveaux d'expérience acceptés
# 3712                       Minimum 5 ans
# 3713                       Minimum 3 ans
# 3714                       Minimum 2 ans
# 3715  Tous niveaux d'expérience acceptés
#
#                                          metier  \
# 0                                  Data analyst
# 1                                 Data engineer
# 2                                  Data analyst
# 3                                  Data analyst
# 4                                  Data analyst
# ...                                         ...
# 3711                 Ingénieur test et recettes
# 3712                                Développeur
# 3713                                Développeur
# 3714  Chef de projet informatique décisionnelle
# 3715                   Architecte développement
#
#                        statut_du_poste  ...  \
# 0               Cadre du secteur privé  ...
# 1               Cadre du secteur privé  ...
# 2               Cadre du secteur privé  ...
# 3               Cadre du secteur privé  ...
# 4               Cadre du secteur privé  ...
# ...                                ...  ...
# 3711            Cadre du secteur privé  ...
# 3712            Cadre du secteur privé  ...
# 3713            Cadre du secteur privé  ...
# 3714  Cadre du secteur public / Armées  ...
# 3715  Cadre du secteur public / Armées  ...
#
#                                      secteur_d_activite        Teletravail  \
# 0     TRAITEMENT DE DONNÉES, HÉBERGEMENT ET ACTIVITÉ...                NaN
# 1     CONSEIL POUR LES AFFAIRES ET AUTRES CONSEILS D...   Partiel possible
# 2                                     AUTRES ASSURANCES   Partiel possible
# 3        CONSEIL EN SYSTÈMES ET LOGICIELS INFORMATIQUES  Ponctuel autorisé
# 4     FABRICATION DE PRODUITS DE CONSOMMATION COURAN...                NaN
# ...                                                 ...                ...
# 3711  AUTRES ACTIVITÉS AUXILIAIRES DE SERVICES FINAN...   Partiel possible
# 3712             VENTE À DISTANCE SUR CATALOGUE GÉNÉRAL                NaN
# 3713     CONSEIL EN SYSTÈMES ET LOGICIELS INFORMATIQUES                NaN
# 3714                   ADMINISTRATION PUBLIQUE GÉNÉRALE  Ponctuel autorisé
# 3715  RECHERCHE-DÉVELOPPEMENT EN AUTRES SCIENCES PHY...   Partiel possible
#
#                                        descriptif_poste  \
# 0     AI&Data  recherche aujourd'hui des Data Analys...
# 1     Auprès d'un de nos clients dans l'univers de l...
# 2     Vous avez envie de donner un nouvel élan à vot...
# 3     Les tâches proposées ?\nSous la supervision du...
# 4     Vos responsabilités comme Data Analyst :\nLa c...
# ...                                                 ...
# 3711  Contexte\nAu sein du Pôle Acquisition, l’équip...
# 3712  Rejoignez Peaksys, venez faire du hors norme v...
# 3713  Passionné(e) par le développement Java et expe...
# 3714  Mission 1 : Pilotage des projets numériques du...
# 3715  Dans le cadre de France 2030, qui promeut le d...
#
#                                        profil_recherche  \
# 0     De formation supérieure en statistiques et mat...
# 1     De formation supérieure Bac+ 4/5, vous justifi...
# 2     Vous possédez un BAC +5 avec une spécialisatio...
# 3     Le profil recherché ?\nPassionné de la Data et...
# 4     De formation supérieure en statistiques, infor...
# ...                                                 ...
# 3711  Profil recherché\nCe que tu peux apporter :\nI...
# 3712  Nous recherchons des collaborateurs ayant une ...
# 3713   Vos qualifications :\nPour vous épanouir en t...
# 3714  Savoir-faire :\nCapacité à conduire un projet ...
# 3715  Connaissances\n ·         Bonnes connaissances...
#
#                          langues  \
# 0     ['Aucune langue attendue']
# 1     ['Aucune langue attendue']
# 2     ['Aucune langue attendue']
# 3     ['Aucune langue attendue']
# 4     ['Aucune langue attendue']
# ...                          ...
# 3711                 ['Anglais']
# 3712  ['Aucune langue attendue']
# 3713  ['Aucune langue attendue']
# 3714  ['Aucune langue attendue']
# 3715  ['Aucune langue attendue']
#
#                                             savoir_etre  \
# 0     ['Capacité à prendre des décisions', "Capacité...
# 1                         ['Aucun savoir-être attendu']
# 2     ['Autonomie', "Capacité d'adaptation", "Capaci...
# 3     ['Autonomie', "Esprit d'équipe", 'Passionne', ...
# 4                            ['Autonomie', 'Pédagogie']
# ...                                                 ...
# 3711  ["Capacité d'adaptation", 'Curiosité', "Esprit...
# 3712  ['Ambition', "Capacité d'adaptation", 'Capacit...
# 3713  ['Capacité à travailler en mode projet', "Capa...
# 3714  ["Capacité d'adaptation", 'Capacité de communi...
# 3715                      ['Aucun savoir-être attendu']
#
#                                            savoir_faire  \
# 0     ['Algorithme', 'Amazon Web Services', 'Base de...
# 1                        ['Aucun savoir-faire attendu']
# 2     ['Langage R', 'Python', 'Spark', 'SQL', 'Trait...
# 3     ['Analyse de données', 'Data Visualisation', '...
# 4     ['Analyse de données', 'Analyse des besoins', ...
# ...                                                 ...
# 3711  ['Test fonctionnel', 'Accompagnement du client...
# 3712  ['Docker', 'GIT', 'Interface de programmation ...
# 3713  ['Apache Maven', 'Amélioration continue', 'Aut...
# 3714  ['Formation continue et professionnelle', 'QS'...
# 3715                     ['Aucun savoir-faire attendu']
#
#                                   descriptif_entreprise nombre_posts  \
# 0     AI&Data est une Agence Data sur trois domaines...           1
# 1     Créée en 2004, VR Conseil est une ESN spéciali...           1
# 2     Entreprise de l'Économie Sociale, la Macif n'a...           1
# 3     Mydral  est une entreprise qui aide ses client...           1
# 4     Notre client, client final dans le secteur ind...           1
# ...                                                 ...          ...
# 3711  MONEXT est un acteur majeur du paiement en Fra...           1
# 3712  Chez Peaksys, filiale Tech de Cdiscount, nous ...           1
# 3713  Amaris Consulting est une société indépendante...           1
# 3714  Employeur de premier plan, la Région Ile-de-Fr...           1
# 3715  L' Inserm est le seul organisme public françai...           1
#
#             duree
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 3711         None
# 3712         None
# 3713         None
# 3714   de 36 mois
# 3715   de 24 mois
#
# [3716 rows x 21 columns]

# %% [markdown]
# # Diviser la colonne deparetement en 2 colonnes  (deparetement et code_postal)

# %%
import re

def retirer_chiffre(departement):
    regex_numeros = re.compile(r'\b\d+\b')

    lieux_propres = []
    for lieu in departement:
        lieu_propre = regex_numeros.sub('', lieu).strip()
        lieux_propres.append(lieu_propre)

    return lieux_propres

# %%
departement_splitted = df['deparetement'].str.split(' - ' , expand=True)
df['ville'] = retirer_chiffre(departement_splitted[0])
df['code_postal'] = departement_splitted[1]
df
# Out:
#                              entreprise type_contrat  \
# 0                               AI&Data          CDI
# 1                            VR CONSEIL          CDI
# 2                                 MACIF          CDI
# 3                                MYDRAL          CDI
# 4     MICHAEL PAGE INTERNATIONAL FRANCE          CDI
# ...                                 ...          ...
# 3711                             MONEXT          CDI
# 3712                          CDISCOUNT          CDI
# 3713                  AMARIS FRANCE SAS          CDI
# 3714               REGION ILE DE FRANCE          CDD
# 3715            DR PARIS IDF CENTRE-EST          CDD
#
#                    deparetement date_publication date_mise_a_jour  \
# 0     Boulogne-Billancourt - 92       2024-02-01       2024-02-01
# 1                 Paris 09 - 75       2023-12-14       2024-01-15
# 2                    Niort - 79       2024-02-07       2024-02-07
# 3                 Paris 02 - 75       2024-02-05       2024-02-05
# 4                   Rennes - 35       2024-01-27       2024-01-27
# ...                         ...              ...              ...
# 3711       Aix-en-Provence - 13       2024-03-08       2024-03-08
# 3712              Bordeaux - 33       2024-03-05       2024-03-05
# 3713            Strasbourg - 67       2024-03-04       2024-03-10
# 3714            Saint-Ouen - 93       2024-02-16       2024-02-16
# 3715              Paris 15 - 75       2024-01-26       2024-03-11
#
#                             salaire    prise_de_poste  \
# 0                        A négocier  Dès que possible
# 1            45 - 75 k€ brut annuel  Dès que possible
# 2                        A négocier  Dès que possible
# 3            40 - 45 k€ brut annuel  Dès que possible
# 4            45 - 55 k€ brut annuel  Dès que possible
# ...                             ...               ...
# 3711                     A négocier  Dès que possible
# 3712                     A négocier  Dès que possible
# 3713                     A négocier  Dès que possible
# 3714                     A négocier  Dès que possible
# 3715  A partir de 35 k€ brut annuel  Dès que possible
#
#                               experience  \
# 0                          Minimum 2 ans
# 1                          Minimum 5 ans
# 2                          Minimum 2 ans
# 3                          Minimum 2 ans
# 4               Aucune expérience exigée
# ...                                  ...
# 3711  Tous niveaux d'expérience acceptés
# 3712                       Minimum 5 ans
# 3713                       Minimum 3 ans
# 3714                       Minimum 2 ans
# 3715  Tous niveaux d'expérience acceptés
#
#                                          metier  \
# 0                                  Data analyst
# 1                                 Data engineer
# 2                                  Data analyst
# 3                                  Data analyst
# 4                                  Data analyst
# ...                                         ...
# 3711                 Ingénieur test et recettes
# 3712                                Développeur
# 3713                                Développeur
# 3714  Chef de projet informatique décisionnelle
# 3715                   Architecte développement
#
#                        statut_du_poste  ...  \
# 0               Cadre du secteur privé  ...
# 1               Cadre du secteur privé  ...
# 2               Cadre du secteur privé  ...
# 3               Cadre du secteur privé  ...
# 4               Cadre du secteur privé  ...
# ...                                ...  ...
# 3711            Cadre du secteur privé  ...
# 3712            Cadre du secteur privé  ...
# 3713            Cadre du secteur privé  ...
# 3714  Cadre du secteur public / Armées  ...
# 3715  Cadre du secteur public / Armées  ...
#
#                                        descriptif_poste  \
# 0     AI&Data  recherche aujourd'hui des Data Analys...
# 1     Auprès d'un de nos clients dans l'univers de l...
# 2     Vous avez envie de donner un nouvel élan à vot...
# 3     Les tâches proposées ?\nSous la supervision du...
# 4     Vos responsabilités comme Data Analyst :\nLa c...
# ...                                                 ...
# 3711  Contexte\nAu sein du Pôle Acquisition, l’équip...
# 3712  Rejoignez Peaksys, venez faire du hors norme v...
# 3713  Passionné(e) par le développement Java et expe...
# 3714  Mission 1 : Pilotage des projets numériques du...
# 3715  Dans le cadre de France 2030, qui promeut le d...
#
#                                        profil_recherche  \
# 0     De formation supérieure en statistiques et mat...
# 1     De formation supérieure Bac+ 4/5, vous justifi...
# 2     Vous possédez un BAC +5 avec une spécialisatio...
# 3     Le profil recherché ?\nPassionné de la Data et...
# 4     De formation supérieure en statistiques, infor...
# ...                                                 ...
# 3711  Profil recherché\nCe que tu peux apporter :\nI...
# 3712  Nous recherchons des collaborateurs ayant une ...
# 3713   Vos qualifications :\nPour vous épanouir en t...
# 3714  Savoir-faire :\nCapacité à conduire un projet ...
# 3715  Connaissances\n ·         Bonnes connaissances...
#
#                          langues  \
# 0     ['Aucune langue attendue']
# 1     ['Aucune langue attendue']
# 2     ['Aucune langue attendue']
# 3     ['Aucune langue attendue']
# 4     ['Aucune langue attendue']
# ...                          ...
# 3711                 ['Anglais']
# 3712  ['Aucune langue attendue']
# 3713  ['Aucune langue attendue']
# 3714  ['Aucune langue attendue']
# 3715  ['Aucune langue attendue']
#
#                                             savoir_etre  \
# 0     ['Capacité à prendre des décisions', "Capacité...
# 1                         ['Aucun savoir-être attendu']
# 2     ['Autonomie', "Capacité d'adaptation", "Capaci...
# 3     ['Autonomie', "Esprit d'équipe", 'Passionne', ...
# 4                            ['Autonomie', 'Pédagogie']
# ...                                                 ...
# 3711  ["Capacité d'adaptation", 'Curiosité', "Esprit...
# 3712  ['Ambition', "Capacité d'adaptation", 'Capacit...
# 3713  ['Capacité à travailler en mode projet', "Capa...
# 3714  ["Capacité d'adaptation", 'Capacité de communi...
# 3715                      ['Aucun savoir-être attendu']
#
#                                            savoir_faire  \
# 0     ['Algorithme', 'Amazon Web Services', 'Base de...
# 1                        ['Aucun savoir-faire attendu']
# 2     ['Langage R', 'Python', 'Spark', 'SQL', 'Trait...
# 3     ['Analyse de données', 'Data Visualisation', '...
# 4     ['Analyse de données', 'Analyse des besoins', ...
# ...                                                 ...
# 3711  ['Test fonctionnel', 'Accompagnement du client...
# 3712  ['Docker', 'GIT', 'Interface de programmation ...
# 3713  ['Apache Maven', 'Amélioration continue', 'Aut...
# 3714  ['Formation continue et professionnelle', 'QS'...
# 3715                     ['Aucun savoir-faire attendu']
#
#                                   descriptif_entreprise nombre_posts  \
# 0     AI&Data est une Agence Data sur trois domaines...           1
# 1     Créée en 2004, VR Conseil est une ESN spéciali...           1
# 2     Entreprise de l'Économie Sociale, la Macif n'a...           1
# 3     Mydral  est une entreprise qui aide ses client...           1
# 4     Notre client, client final dans le secteur ind...           1
# ...                                                 ...          ...
# 3711  MONEXT est un acteur majeur du paiement en Fra...           1
# 3712  Chez Peaksys, filiale Tech de Cdiscount, nous ...           1
# 3713  Amaris Consulting est une société indépendante...           1
# 3714  Employeur de premier plan, la Région Ile-de-Fr...           1
# 3715  L' Inserm est le seul organisme public françai...           1
#
#             duree                 ville code_postal
# 0            None  Boulogne-Billancourt          92
# 1            None                 Paris          75
# 2            None                 Niort          79
# 3            None                 Paris          75
# 4            None                Rennes          35
# ...           ...                   ...         ...
# 3711         None       Aix-en-Provence          13
# 3712         None              Bordeaux          33
# 3713         None            Strasbourg          67
# 3714   de 36 mois            Saint-Ouen          93
# 3715   de 24 mois                 Paris          75
#
# [3716 rows x 23 columns]

# %% [markdown]
# Suppression les lignes qui ont un code_postal NULL

# %%
df = df.dropna(subset=['code_postal'])
df = df.drop('deparetement', axis=1)

# %%
df
# Out:
#                              entreprise type_contrat date_publication  \
# 0                               AI&Data          CDI       2024-02-01
# 1                            VR CONSEIL          CDI       2023-12-14
# 2                                 MACIF          CDI       2024-02-07
# 3                                MYDRAL          CDI       2024-02-05
# 4     MICHAEL PAGE INTERNATIONAL FRANCE          CDI       2024-01-27
# ...                                 ...          ...              ...
# 3711                             MONEXT          CDI       2024-03-08
# 3712                          CDISCOUNT          CDI       2024-03-05
# 3713                  AMARIS FRANCE SAS          CDI       2024-03-04
# 3714               REGION ILE DE FRANCE          CDD       2024-02-16
# 3715            DR PARIS IDF CENTRE-EST          CDD       2024-01-26
#
#      date_mise_a_jour                        salaire    prise_de_poste  \
# 0          2024-02-01                     A négocier  Dès que possible
# 1          2024-01-15         45 - 75 k€ brut annuel  Dès que possible
# 2          2024-02-07                     A négocier  Dès que possible
# 3          2024-02-05         40 - 45 k€ brut annuel  Dès que possible
# 4          2024-01-27         45 - 55 k€ brut annuel  Dès que possible
# ...               ...                            ...               ...
# 3711       2024-03-08                     A négocier  Dès que possible
# 3712       2024-03-05                     A négocier  Dès que possible
# 3713       2024-03-10                     A négocier  Dès que possible
# 3714       2024-02-16                     A négocier  Dès que possible
# 3715       2024-03-11  A partir de 35 k€ brut annuel  Dès que possible
#
#                               experience  \
# 0                          Minimum 2 ans
# 1                          Minimum 5 ans
# 2                          Minimum 2 ans
# 3                          Minimum 2 ans
# 4               Aucune expérience exigée
# ...                                  ...
# 3711  Tous niveaux d'expérience acceptés
# 3712                       Minimum 5 ans
# 3713                       Minimum 3 ans
# 3714                       Minimum 2 ans
# 3715  Tous niveaux d'expérience acceptés
#
#                                          metier  \
# 0                                  Data analyst
# 1                                 Data engineer
# 2                                  Data analyst
# 3                                  Data analyst
# 4                                  Data analyst
# ...                                         ...
# 3711                 Ingénieur test et recettes
# 3712                                Développeur
# 3713                                Développeur
# 3714  Chef de projet informatique décisionnelle
# 3715                   Architecte développement
#
#                        statut_du_poste zone_de_deplacement  ...  \
# 0               Cadre du secteur privé           Nationale  ...
# 1               Cadre du secteur privé  Pas de déplacement  ...
# 2               Cadre du secteur privé  Pas de déplacement  ...
# 3               Cadre du secteur privé           Régionale  ...
# 4               Cadre du secteur privé  Pas de déplacement  ...
# ...                                ...                 ...  ...
# 3711            Cadre du secteur privé  Pas de déplacement  ...
# 3712            Cadre du secteur privé  Pas de déplacement  ...
# 3713            Cadre du secteur privé  Pas de déplacement  ...
# 3714  Cadre du secteur public / Armées  Pas de déplacement  ...
# 3715  Cadre du secteur public / Armées  Pas de déplacement  ...
#
#                                        descriptif_poste  \
# 0     AI&Data  recherche aujourd'hui des Data Analys...
# 1     Auprès d'un de nos clients dans l'univers de l...
# 2     Vous avez envie de donner un nouvel élan à vot...
# 3     Les tâches proposées ?\nSous la supervision du...
# 4     Vos responsabilités comme Data Analyst :\nLa c...
# ...                                                 ...
# 3711  Contexte\nAu sein du Pôle Acquisition, l’équip...
# 3712  Rejoignez Peaksys, venez faire du hors norme v...
# 3713  Passionné(e) par le développement Java et expe...
# 3714  Mission 1 : Pilotage des projets numériques du...
# 3715  Dans le cadre de France 2030, qui promeut le d...
#
#                                        profil_recherche  \
# 0     De formation supérieure en statistiques et mat...
# 1     De formation supérieure Bac+ 4/5, vous justifi...
# 2     Vous possédez un BAC +5 avec une spécialisatio...
# 3     Le profil recherché ?\nPassionné de la Data et...
# 4     De formation supérieure en statistiques, infor...
# ...                                                 ...
# 3711  Profil recherché\nCe que tu peux apporter :\nI...
# 3712  Nous recherchons des collaborateurs ayant une ...
# 3713   Vos qualifications :\nPour vous épanouir en t...
# 3714  Savoir-faire :\nCapacité à conduire un projet ...
# 3715  Connaissances\n ·         Bonnes connaissances...
#
#                          langues  \
# 0     ['Aucune langue attendue']
# 1     ['Aucune langue attendue']
# 2     ['Aucune langue attendue']
# 3     ['Aucune langue attendue']
# 4     ['Aucune langue attendue']
# ...                          ...
# 3711                 ['Anglais']
# 3712  ['Aucune langue attendue']
# 3713  ['Aucune langue attendue']
# 3714  ['Aucune langue attendue']
# 3715  ['Aucune langue attendue']
#
#                                             savoir_etre  \
# 0     ['Capacité à prendre des décisions', "Capacité...
# 1                         ['Aucun savoir-être attendu']
# 2     ['Autonomie', "Capacité d'adaptation", "Capaci...
# 3     ['Autonomie', "Esprit d'équipe", 'Passionne', ...
# 4                            ['Autonomie', 'Pédagogie']
# ...                                                 ...
# 3711  ["Capacité d'adaptation", 'Curiosité', "Esprit...
# 3712  ['Ambition', "Capacité d'adaptation", 'Capacit...
# 3713  ['Capacité à travailler en mode projet', "Capa...
# 3714  ["Capacité d'adaptation", 'Capacité de communi...
# 3715                      ['Aucun savoir-être attendu']
#
#                                            savoir_faire  \
# 0     ['Algorithme', 'Amazon Web Services', 'Base de...
# 1                        ['Aucun savoir-faire attendu']
# 2     ['Langage R', 'Python', 'Spark', 'SQL', 'Trait...
# 3     ['Analyse de données', 'Data Visualisation', '...
# 4     ['Analyse de données', 'Analyse des besoins', ...
# ...                                                 ...
# 3711  ['Test fonctionnel', 'Accompagnement du client...
# 3712  ['Docker', 'GIT', 'Interface de programmation ...
# 3713  ['Apache Maven', 'Amélioration continue', 'Aut...
# 3714  ['Formation continue et professionnelle', 'QS'...
# 3715                     ['Aucun savoir-faire attendu']
#
#                                   descriptif_entreprise nombre_posts  \
# 0     AI&Data est une Agence Data sur trois domaines...           1
# 1     Créée en 2004, VR Conseil est une ESN spéciali...           1
# 2     Entreprise de l'Économie Sociale, la Macif n'a...           1
# 3     Mydral  est une entreprise qui aide ses client...           1
# 4     Notre client, client final dans le secteur ind...           1
# ...                                                 ...          ...
# 3711  MONEXT est un acteur majeur du paiement en Fra...           1
# 3712  Chez Peaksys, filiale Tech de Cdiscount, nous ...           1
# 3713  Amaris Consulting est une société indépendante...           1
# 3714  Employeur de premier plan, la Région Ile-de-Fr...           1
# 3715  L' Inserm est le seul organisme public françai...           1
#
#             duree                 ville code_postal
# 0            None  Boulogne-Billancourt          92
# 1            None                 Paris          75
# 2            None                 Niort          79
# 3            None                 Paris          75
# 4            None                Rennes          35
# ...           ...                   ...         ...
# 3711         None       Aix-en-Provence          13
# 3712         None              Bordeaux          33
# 3713         None            Strasbourg          67
# 3714   de 36 mois            Saint-Ouen          93
# 3715   de 24 mois                 Paris          75
#
# [3686 rows x 22 columns]

# %% [markdown]
# # Convertire la colonne experience en entier

# %%
df['experience']= df['experience'].str.extract(r'(\d+)', expand=False).fillna(0)
df['experience'] = df['experience'].astype(int)
df
# Out:
#                              entreprise type_contrat date_publication  \
# 0                               AI&Data          CDI       2024-02-01
# 1                            VR CONSEIL          CDI       2023-12-14
# 2                                 MACIF          CDI       2024-02-07
# 3                                MYDRAL          CDI       2024-02-05
# 4     MICHAEL PAGE INTERNATIONAL FRANCE          CDI       2024-01-27
# ...                                 ...          ...              ...
# 3711                             MONEXT          CDI       2024-03-08
# 3712                          CDISCOUNT          CDI       2024-03-05
# 3713                  AMARIS FRANCE SAS          CDI       2024-03-04
# 3714               REGION ILE DE FRANCE          CDD       2024-02-16
# 3715            DR PARIS IDF CENTRE-EST          CDD       2024-01-26
#
#      date_mise_a_jour                        salaire    prise_de_poste  \
# 0          2024-02-01                     A négocier  Dès que possible
# 1          2024-01-15         45 - 75 k€ brut annuel  Dès que possible
# 2          2024-02-07                     A négocier  Dès que possible
# 3          2024-02-05         40 - 45 k€ brut annuel  Dès que possible
# 4          2024-01-27         45 - 55 k€ brut annuel  Dès que possible
# ...               ...                            ...               ...
# 3711       2024-03-08                     A négocier  Dès que possible
# 3712       2024-03-05                     A négocier  Dès que possible
# 3713       2024-03-10                     A négocier  Dès que possible
# 3714       2024-02-16                     A négocier  Dès que possible
# 3715       2024-03-11  A partir de 35 k€ brut annuel  Dès que possible
#
#       experience                                     metier  \
# 0              2                               Data analyst
# 1              5                              Data engineer
# 2              2                               Data analyst
# 3              2                               Data analyst
# 4              0                               Data analyst
# ...          ...                                        ...
# 3711           0                 Ingénieur test et recettes
# 3712           5                                Développeur
# 3713           3                                Développeur
# 3714           2  Chef de projet informatique décisionnelle
# 3715           0                   Architecte développement
#
#                        statut_du_poste zone_de_deplacement  ...  \
# 0               Cadre du secteur privé           Nationale  ...
# 1               Cadre du secteur privé  Pas de déplacement  ...
# 2               Cadre du secteur privé  Pas de déplacement  ...
# 3               Cadre du secteur privé           Régionale  ...
# 4               Cadre du secteur privé  Pas de déplacement  ...
# ...                                ...                 ...  ...
# 3711            Cadre du secteur privé  Pas de déplacement  ...
# 3712            Cadre du secteur privé  Pas de déplacement  ...
# 3713            Cadre du secteur privé  Pas de déplacement  ...
# 3714  Cadre du secteur public / Armées  Pas de déplacement  ...
# 3715  Cadre du secteur public / Armées  Pas de déplacement  ...
#
#                                        descriptif_poste  \
# 0     AI&Data  recherche aujourd'hui des Data Analys...
# 1     Auprès d'un de nos clients dans l'univers de l...
# 2     Vous avez envie de donner un nouvel élan à vot...
# 3     Les tâches proposées ?\nSous la supervision du...
# 4     Vos responsabilités comme Data Analyst :\nLa c...
# ...                                                 ...
# 3711  Contexte\nAu sein du Pôle Acquisition, l’équip...
# 3712  Rejoignez Peaksys, venez faire du hors norme v...
# 3713  Passionné(e) par le développement Java et expe...
# 3714  Mission 1 : Pilotage des projets numériques du...
# 3715  Dans le cadre de France 2030, qui promeut le d...
#
#                                        profil_recherche  \
# 0     De formation supérieure en statistiques et mat...
# 1     De formation supérieure Bac+ 4/5, vous justifi...
# 2     Vous possédez un BAC +5 avec une spécialisatio...
# 3     Le profil recherché ?\nPassionné de la Data et...
# 4     De formation supérieure en statistiques, infor...
# ...                                                 ...
# 3711  Profil recherché\nCe que tu peux apporter :\nI...
# 3712  Nous recherchons des collaborateurs ayant une ...
# 3713   Vos qualifications :\nPour vous épanouir en t...
# 3714  Savoir-faire :\nCapacité à conduire un projet ...
# 3715  Connaissances\n ·         Bonnes connaissances...
#
#                          langues  \
# 0     ['Aucune langue attendue']
# 1     ['Aucune langue attendue']
# 2     ['Aucune langue attendue']
# 3     ['Aucune langue attendue']
# 4     ['Aucune langue attendue']
# ...                          ...
# 3711                 ['Anglais']
# 3712  ['Aucune langue attendue']
# 3713  ['Aucune langue attendue']
# 3714  ['Aucune langue attendue']
# 3715  ['Aucune langue attendue']
#
#                                             savoir_etre  \
# 0     ['Capacité à prendre des décisions', "Capacité...
# 1                         ['Aucun savoir-être attendu']
# 2     ['Autonomie', "Capacité d'adaptation", "Capaci...
# 3     ['Autonomie', "Esprit d'équipe", 'Passionne', ...
# 4                            ['Autonomie', 'Pédagogie']
# ...                                                 ...
# 3711  ["Capacité d'adaptation", 'Curiosité', "Esprit...
# 3712  ['Ambition', "Capacité d'adaptation", 'Capacit...
# 3713  ['Capacité à travailler en mode projet', "Capa...
# 3714  ["Capacité d'adaptation", 'Capacité de communi...
# 3715                      ['Aucun savoir-être attendu']
#
#                                            savoir_faire  \
# 0     ['Algorithme', 'Amazon Web Services', 'Base de...
# 1                        ['Aucun savoir-faire attendu']
# 2     ['Langage R', 'Python', 'Spark', 'SQL', 'Trait...
# 3     ['Analyse de données', 'Data Visualisation', '...
# 4     ['Analyse de données', 'Analyse des besoins', ...
# ...                                                 ...
# 3711  ['Test fonctionnel', 'Accompagnement du client...
# 3712  ['Docker', 'GIT', 'Interface de programmation ...
# 3713  ['Apache Maven', 'Amélioration continue', 'Aut...
# 3714  ['Formation continue et professionnelle', 'QS'...
# 3715                     ['Aucun savoir-faire attendu']
#
#                                   descriptif_entreprise nombre_posts  \
# 0     AI&Data est une Agence Data sur trois domaines...           1
# 1     Créée en 2004, VR Conseil est une ESN spéciali...           1
# 2     Entreprise de l'Économie Sociale, la Macif n'a...           1
# 3     Mydral  est une entreprise qui aide ses client...           1
# 4     Notre client, client final dans le secteur ind...           1
# ...                                                 ...          ...
# 3711  MONEXT est un acteur majeur du paiement en Fra...           1
# 3712  Chez Peaksys, filiale Tech de Cdiscount, nous ...           1
# 3713  Amaris Consulting est une société indépendante...           1
# 3714  Employeur de premier plan, la Région Ile-de-Fr...           1
# 3715  L' Inserm est le seul organisme public françai...           1
#
#             duree                 ville code_postal
# 0            None  Boulogne-Billancourt          92
# 1            None                 Paris          75
# 2            None                 Niort          79
# 3            None                 Paris          75
# 4            None                Rennes          35
# ...           ...                   ...         ...
# 3711         None       Aix-en-Provence          13
# 3712         None              Bordeaux          33
# 3713         None            Strasbourg          67
# 3714   de 36 mois            Saint-Ouen          93
# 3715   de 24 mois                 Paris          75
#
# [3686 rows x 22 columns]

# %% [markdown]
# # Nettoyage de la colonne salaire

# %%
def nettoyer_salaire(salaire):
    if salaire == 'A négocier':
        return None
    elif 'A partir de' in salaire:
        return float(salaire.split(' ')[3])
    else:
        valeurs = [float(x) for x in salaire.split(' ') if x.isdigit()]
        return np.mean(valeurs)

df['salaire'] = df['salaire'].apply(nettoyer_salaire)
df
# Out:
#                              entreprise type_contrat date_publication  \
# 0                               AI&Data          CDI       2024-02-01
# 1                            VR CONSEIL          CDI       2023-12-14
# 2                                 MACIF          CDI       2024-02-07
# 3                                MYDRAL          CDI       2024-02-05
# 4     MICHAEL PAGE INTERNATIONAL FRANCE          CDI       2024-01-27
# ...                                 ...          ...              ...
# 3711                             MONEXT          CDI       2024-03-08
# 3712                          CDISCOUNT          CDI       2024-03-05
# 3713                  AMARIS FRANCE SAS          CDI       2024-03-04
# 3714               REGION ILE DE FRANCE          CDD       2024-02-16
# 3715            DR PARIS IDF CENTRE-EST          CDD       2024-01-26
#
#      date_mise_a_jour  salaire    prise_de_poste  experience  \
# 0          2024-02-01      NaN  Dès que possible           2
# 1          2024-01-15     60.0  Dès que possible           5
# 2          2024-02-07      NaN  Dès que possible           2
# 3          2024-02-05     42.5  Dès que possible           2
# 4          2024-01-27     50.0  Dès que possible           0
# ...               ...      ...               ...         ...
# 3711       2024-03-08      NaN  Dès que possible           0
# 3712       2024-03-05      NaN  Dès que possible           5
# 3713       2024-03-10      NaN  Dès que possible           3
# 3714       2024-02-16      NaN  Dès que possible           2
# 3715       2024-03-11     35.0  Dès que possible           0
#
#                                          metier  \
# 0                                  Data analyst
# 1                                 Data engineer
# 2                                  Data analyst
# 3                                  Data analyst
# 4                                  Data analyst
# ...                                         ...
# 3711                 Ingénieur test et recettes
# 3712                                Développeur
# 3713                                Développeur
# 3714  Chef de projet informatique décisionnelle
# 3715                   Architecte développement
#
#                        statut_du_poste zone_de_deplacement  ...  \
# 0               Cadre du secteur privé           Nationale  ...
# 1               Cadre du secteur privé  Pas de déplacement  ...
# 2               Cadre du secteur privé  Pas de déplacement  ...
# 3               Cadre du secteur privé           Régionale  ...
# 4               Cadre du secteur privé  Pas de déplacement  ...
# ...                                ...                 ...  ...
# 3711            Cadre du secteur privé  Pas de déplacement  ...
# 3712            Cadre du secteur privé  Pas de déplacement  ...
# 3713            Cadre du secteur privé  Pas de déplacement  ...
# 3714  Cadre du secteur public / Armées  Pas de déplacement  ...
# 3715  Cadre du secteur public / Armées  Pas de déplacement  ...
#
#                                        descriptif_poste  \
# 0     AI&Data  recherche aujourd'hui des Data Analys...
# 1     Auprès d'un de nos clients dans l'univers de l...
# 2     Vous avez envie de donner un nouvel élan à vot...
# 3     Les tâches proposées ?\nSous la supervision du...
# 4     Vos responsabilités comme Data Analyst :\nLa c...
# ...                                                 ...
# 3711  Contexte\nAu sein du Pôle Acquisition, l’équip...
# 3712  Rejoignez Peaksys, venez faire du hors norme v...
# 3713  Passionné(e) par le développement Java et expe...
# 3714  Mission 1 : Pilotage des projets numériques du...
# 3715  Dans le cadre de France 2030, qui promeut le d...
#
#                                        profil_recherche  \
# 0     De formation supérieure en statistiques et mat...
# 1     De formation supérieure Bac+ 4/5, vous justifi...
# 2     Vous possédez un BAC +5 avec une spécialisatio...
# 3     Le profil recherché ?\nPassionné de la Data et...
# 4     De formation supérieure en statistiques, infor...
# ...                                                 ...
# 3711  Profil recherché\nCe que tu peux apporter :\nI...
# 3712  Nous recherchons des collaborateurs ayant une ...
# 3713   Vos qualifications :\nPour vous épanouir en t...
# 3714  Savoir-faire :\nCapacité à conduire un projet ...
# 3715  Connaissances\n ·         Bonnes connaissances...
#
#                          langues  \
# 0     ['Aucune langue attendue']
# 1     ['Aucune langue attendue']
# 2     ['Aucune langue attendue']
# 3     ['Aucune langue attendue']
# 4     ['Aucune langue attendue']
# ...                          ...
# 3711                 ['Anglais']
# 3712  ['Aucune langue attendue']
# 3713  ['Aucune langue attendue']
# 3714  ['Aucune langue attendue']
# 3715  ['Aucune langue attendue']
#
#                                             savoir_etre  \
# 0     ['Capacité à prendre des décisions', "Capacité...
# 1                         ['Aucun savoir-être attendu']
# 2     ['Autonomie', "Capacité d'adaptation", "Capaci...
# 3     ['Autonomie', "Esprit d'équipe", 'Passionne', ...
# 4                            ['Autonomie', 'Pédagogie']
# ...                                                 ...
# 3711  ["Capacité d'adaptation", 'Curiosité', "Esprit...
# 3712  ['Ambition', "Capacité d'adaptation", 'Capacit...
# 3713  ['Capacité à travailler en mode projet', "Capa...
# 3714  ["Capacité d'adaptation", 'Capacité de communi...
# 3715                      ['Aucun savoir-être attendu']
#
#                                            savoir_faire  \
# 0     ['Algorithme', 'Amazon Web Services', 'Base de...
# 1                        ['Aucun savoir-faire attendu']
# 2     ['Langage R', 'Python', 'Spark', 'SQL', 'Trait...
# 3     ['Analyse de données', 'Data Visualisation', '...
# 4     ['Analyse de données', 'Analyse des besoins', ...
# ...                                                 ...
# 3711  ['Test fonctionnel', 'Accompagnement du client...
# 3712  ['Docker', 'GIT', 'Interface de programmation ...
# 3713  ['Apache Maven', 'Amélioration continue', 'Aut...
# 3714  ['Formation continue et professionnelle', 'QS'...
# 3715                     ['Aucun savoir-faire attendu']
#
#                                   descriptif_entreprise nombre_posts  \
# 0     AI&Data est une Agence Data sur trois domaines...           1
# 1     Créée en 2004, VR Conseil est une ESN spéciali...           1
# 2     Entreprise de l'Économie Sociale, la Macif n'a...           1
# 3     Mydral  est une entreprise qui aide ses client...           1
# 4     Notre client, client final dans le secteur ind...           1
# ...                                                 ...          ...
# 3711  MONEXT est un acteur majeur du paiement en Fra...           1
# 3712  Chez Peaksys, filiale Tech de Cdiscount, nous ...           1
# 3713  Amaris Consulting est une société indépendante...           1
# 3714  Employeur de premier plan, la Région Ile-de-Fr...           1
# 3715  L' Inserm est le seul organisme public françai...           1
#
#             duree                 ville code_postal
# 0            None  Boulogne-Billancourt          92
# 1            None                 Paris          75
# 2            None                 Niort          79
# 3            None                 Paris          75
# 4            None                Rennes          35
# ...           ...                   ...         ...
# 3711         None       Aix-en-Provence          13
# 3712         None              Bordeaux          33
# 3713         None            Strasbourg          67
# 3714   de 36 mois            Saint-Ouen          93
# 3715   de 24 mois                 Paris          75
#
# [3686 rows x 22 columns]

# %%
dep_df = pd.read_csv("Departements.csv")
dep_df
# Out:
#     code_postal              departement
# 0            01                      Ain
# 1            02                    Aisne
# 2            03                   Allier
# 3            04  Alpes-de-haute-provence
# 4            05             Hautes-Alpes
# ..          ...                      ...
# 96          971               Guadeloupe
# 97          972               Martinique
# 98          973                   Guyane
# 99          974               La Réunion
# 100         975                  Mayotte
#
# [101 rows x 2 columns]

# %%
df_join = pd.merge(df, dep_df, on='code_postal', how='inner')
df_join
# Out:
#                              entreprise type_contrat date_publication  \
# 0                               AI&Data          CDI       2024-02-01
# 1                       BLUE CONSULTING          CDI       2023-11-29
# 2                    CAF Hauts-de-Seine          CDI       2024-02-07
# 3                               Avanade          CDI       2024-01-16
# 4                          Lydia CHERFI          CDI       2024-01-24
# ...                                 ...          ...              ...
# 3679  MICHAEL PAGE INTERNATIONAL FRANCE          CDI       2024-03-16
# 3680              Siléane Saint-Etienne          CDI       2024-03-05
# 3681           AKKODIS CLERMONT-FERRAND          CDI       2024-03-07
# 3682                            EURENCO          CDI       2024-02-19
# 3683                          API & YOU          CDI       2024-01-16
#
#      date_mise_a_jour  salaire    prise_de_poste  experience  \
# 0          2024-02-01      NaN  Dès que possible           2
# 1          2024-01-17     55.0        02/01/2024           5
# 2          2024-02-07     34.0  Dès que possible           0
# 3          2024-01-16     65.0  Dès que possible           7
# 4          2024-01-24      NaN  Dès que possible           4
# ...               ...      ...               ...         ...
# 3679       2024-03-16     52.5  Dès que possible           0
# 3680       2024-03-07      NaN  Dès que possible           5
# 3681       2024-03-07      NaN  Dès que possible           3
# 3682       2024-02-19     46.0  Dès que possible           0
# 3683       2024-03-05     32.5  Dès que possible           0
#
#                                  metier                 statut_du_poste  \
# 0                          Data analyst          Cadre du secteur privé
# 1                          Data analyst          Cadre du secteur privé
# 2                          Data analyst          Cadre du secteur privé
# 3                    Chief Data Officer          Cadre du secteur privé
# 4                          Data analyst          Cadre du secteur privé
# ...                                 ...                             ...
# 3679  Responsable sécurité informatique          Cadre du secteur privé
# 3680                        Développeur          Cadre du secteur privé
# 3681                  Ingénieur système          Cadre du secteur privé
# 3682         Architecte infrastructures          Cadre du secteur privé
# 3683                  Ingénieur réseaux  Agent de maîtrise / Technicien
#
#      zone_de_deplacement  ...  \
# 0              Nationale  ...
# 1              Régionale  ...
# 2              Nationale  ...
# 3              Régionale  ...
# 4              Nationale  ...
# ...                  ...  ...
# 3679  Pas de déplacement  ...
# 3680    Union Européenne  ...
# 3681  Pas de déplacement  ...
# 3682  Pas de déplacement  ...
# 3683  Pas de déplacement  ...
#
#                                        profil_recherche  \
# 0     De formation supérieure en statistiques et mat...
# 1     Savoir-être :\n- Avoir le sens de l écoute et ...
# 2     Un niveau bac+ 3 souhaité dans le domaine écon...
# 3     De façon concrète \n En tant que Manager Data ...
# 4     Vous avez acquis au moins 4 ans des compétence...
# ...                                                 ...
# 3679  Ingénieur ou issu d'une formation supérieure (...
# 3680   Votre profil\n Vous avez obtenu un diplôme en...
# 3681  Votre profil:\nDe formation supérieure en écol...
# 3682  De formation supérieure en Informatique (BAC+3...
# 3683  Profil recherché :\nDe formation BAC + 5 en in...
#
#                          langues  \
# 0     ['Aucune langue attendue']
# 1     ['Aucune langue attendue']
# 2     ['Aucune langue attendue']
# 3        ['Français', 'Anglais']
# 4     ['Aucune langue attendue']
# ...                          ...
# 3679  ['Aucune langue attendue']
# 3680  ['Aucune langue attendue']
# 3681                 ['Anglais']
# 3682  ['Aucune langue attendue']
# 3683                 ['Anglais']
#
#                                             savoir_etre  \
# 0     ['Capacité à prendre des décisions', "Capacité...
# 1     ["Capacité d'analyse", 'Capacité d’écoute', 'C...
# 2                         ['Aucun savoir-être attendu']
# 3                     ["Esprit d'équipe", 'Leadership']
# 4                         ['Aucun savoir-être attendu']
# ...                                                 ...
# 3679  ["Esprit d'équipe", 'Rigueur', "Sens de l'orga...
# 3680  ['Autonomie', 'Capacité de communication', 'Fo...
# 3681  ['Agilité', 'Ambition', 'Audace', 'Créativité'...
# 3682  ['Autonomie', 'Dynamisme', "Esprit d'équipe", ...
# 3683  ['Autonomie', "Capacité d'analyse", 'Capacité ...
#
#                                            savoir_faire  \
# 0     ['Algorithme', 'Amazon Web Services', 'Base de...
# 1     ['Analyse de données', 'Analyse technique', 'D...
# 2     ['Analyse de données', 'Analyse financière', '...
# 3     ['Communication', 'Gestion de projet', 'Règlem...
# 4                        ['Aucun savoir-faire attendu']
# ...                                                 ...
# 3679  ['Administration système et réseau', 'Analyse ...
# 3680  ['C sharp', 'C++', 'Management des personnes',...
# 3681  ['Réseau électrique', 'Accompagnement du clien...
# 3682  ['Qualité', 'Archivage', 'Certification ITIL',...
# 3683  ['Linux', 'Accompagnement du client', 'Gestion...
#
#                                   descriptif_entreprise nombre_posts duree  \
# 0     AI&Data est une Agence Data sur trois domaines...           1   None
# 1     La société BLUE CONSULTING, Entreprise de serv...           1   None
# 2     La Caf des Hauts-de-Seine, c’est...\n630 colla...           1   None
# 3     Avanade France, des experts Microsoft et ses p...           1   None
# 4     MAKE IT HAPPEN - Depuis 2001, PREREQUIS mise s...           1   None
# ...                                                 ...          ...   ...
# 3679  Le SDIS 42 (Service Départemental d'Incendie e...           1   None
# 3680  SILEANE spécialiste en ROBOTIQUE et VISION, en...           1   None
# 3681  Akkodis, est un acteur mondial de l'ingénierie...           1   None
# 3682  Leader européen dans le domaine des explosifs ...           1   None
# 3683  Api & You, agence conseil, communication et e-...           1   None
#
#                      ville code_postal     departement
# 0     Boulogne-Billancourt          92  Hauts-de-seine
# 1         Levallois-Perret          92  Hauts-de-seine
# 2                 Nanterre          92  Hauts-de-seine
# 3      Issy-les-Moulineaux          92  Hauts-de-seine
# 4        Neuilly-sur-Seine          92  Hauts-de-seine
# ...                    ...         ...             ...
# 3679         Saint-Étienne          42           Loire
# 3680         Saint-Étienne          42           Loire
# 3681                Roanne          42           Loire
# 3682              Bergerac          24        Dordogne
# 3683               Poligny          39            Jura
#
# [3684 rows x 23 columns]

# %%
df_join["departement"].unique()
# Out:
# array(['Hauts-de-seine', 'Paris', 'Deux-Sèvres', 'Ile-et-vilaine',
#        'Alpes-Maritimes', 'Rhône', 'Nord', 'Bouches-du-rhone', 'Eure',
#        'Haute-Savoie', 'Mayenne', 'Hérault', 'Marne', 'Isère', 'Yvelines',
#        'Loire-Atlantique', 'Finistère', 'Gironde', 'Bas-Rhin',
#        'Val-de-Marne', 'Ardèche', "Val-d'Oise", 'Loiret', 'Haute-Garonne',
#        'Moselle', 'Vendée', 'Essonne', 'Calvados', 'Seine-Saint-Denis',
#        'Somme', 'Savoie', 'Oise', 'Puy-de-dome', 'Pyrénées-Orientales',
#        'Charente-Maritime', 'Meurthe-et-moselle', 'Martinique',
#        "Côte-d'or", 'Morbihan', 'Creuse', 'Var', 'Haute-Vienne',
#        'Charente', 'Pyrénées-Atlantiques', 'Vaucluse', 'Seine-et-Marne',
#        'La Réunion', 'Sarthe', 'Côtes-Armor', 'Doubs', 'Drôme',
#        'Eure-et-loir', 'Corrèze', 'Maine-et-loire', 'Indre-et-loire',
#        'Ain', 'Seine-Maritime', 'Gers', 'Lot-et-Garonne', 'Vienne',
#        'Vosges', 'Haut-Rhin', 'Saône-et-Loire', 'Haute-Saônsaone',
#        'Tarn-et-Garonne', 'Cher', 'Landes', 'Nièvre', 'Hautes-Alpes',
#        'Gard', 'Aude', 'Aube', 'Yonne', 'Loir-et-cher', 'Pas-de-Calais',
#        'Manche', 'Lot', 'Allier', 'Territoire-de-Belfort', 'Corse-du-Sud',
#        'Haute-Marne', 'Ariège', 'Aveyron', 'Loire', 'Dordogne', 'Jura'],
#       dtype=object)

# %%
df_join.to_csv(f'Scrapped_Data/Merge_data_cybSec_ancienne/Apec_data_total_merged_filred_cleaned.csv', index=False)

# %%
df_join
# Out:
#                              entreprise type_contrat date_publication  \
# 0                               AI&Data          CDI       2024-02-01
# 1                       BLUE CONSULTING          CDI       2023-11-29
# 2                    CAF Hauts-de-Seine          CDI       2024-02-07
# 3                               Avanade          CDI       2024-01-16
# 4                          Lydia CHERFI          CDI       2024-01-24
# ...                                 ...          ...              ...
# 3679  MICHAEL PAGE INTERNATIONAL FRANCE          CDI       2024-03-16
# 3680              Siléane Saint-Etienne          CDI       2024-03-05
# 3681           AKKODIS CLERMONT-FERRAND          CDI       2024-03-07
# 3682                            EURENCO          CDI       2024-02-19
# 3683                          API & YOU          CDI       2024-01-16
#
#      date_mise_a_jour  salaire    prise_de_poste  experience  \
# 0          2024-02-01      NaN  Dès que possible           2
# 1          2024-01-17     55.0        02/01/2024           5
# 2          2024-02-07     34.0  Dès que possible           0
# 3          2024-01-16     65.0  Dès que possible           7
# 4          2024-01-24      NaN  Dès que possible           4
# ...               ...      ...               ...         ...
# 3679       2024-03-16     52.5  Dès que possible           0
# 3680       2024-03-07      NaN  Dès que possible           5
# 3681       2024-03-07      NaN  Dès que possible           3
# 3682       2024-02-19     46.0  Dès que possible           0
# 3683       2024-03-05     32.5  Dès que possible           0
#
#                                  metier                 statut_du_poste  \
# 0                          Data analyst          Cadre du secteur privé
# 1                          Data analyst          Cadre du secteur privé
# 2                          Data analyst          Cadre du secteur privé
# 3                    Chief Data Officer          Cadre du secteur privé
# 4                          Data analyst          Cadre du secteur privé
# ...                                 ...                             ...
# 3679  Responsable sécurité informatique          Cadre du secteur privé
# 3680                        Développeur          Cadre du secteur privé
# 3681                  Ingénieur système          Cadre du secteur privé
# 3682         Architecte infrastructures          Cadre du secteur privé
# 3683                  Ingénieur réseaux  Agent de maîtrise / Technicien
#
#      zone_de_deplacement  ...  \
# 0              Nationale  ...
# 1              Régionale  ...
# 2              Nationale  ...
# 3              Régionale  ...
# 4              Nationale  ...
# ...                  ...  ...
# 3679  Pas de déplacement  ...
# 3680    Union Européenne  ...
# 3681  Pas de déplacement  ...
# 3682  Pas de déplacement  ...
# 3683  Pas de déplacement  ...
#
#                                        profil_recherche  \
# 0     De formation supérieure en statistiques et mat...
# 1     Savoir-être :\n- Avoir le sens de l écoute et ...
# 2     Un niveau bac+ 3 souhaité dans le domaine écon...
# 3     De façon concrète \n En tant que Manager Data ...
# 4     Vous avez acquis au moins 4 ans des compétence...
# ...                                                 ...
# 3679  Ingénieur ou issu d'une formation supérieure (...
# 3680   Votre profil\n Vous avez obtenu un diplôme en...
# 3681  Votre profil:\nDe formation supérieure en écol...
# 3682  De formation supérieure en Informatique (BAC+3...
# 3683  Profil recherché :\nDe formation BAC + 5 en in...
#
#                          langues  \
# 0     ['Aucune langue attendue']
# 1     ['Aucune langue attendue']
# 2     ['Aucune langue attendue']
# 3        ['Français', 'Anglais']
# 4     ['Aucune langue attendue']
# ...                          ...
# 3679  ['Aucune langue attendue']
# 3680  ['Aucune langue attendue']
# 3681                 ['Anglais']
# 3682  ['Aucune langue attendue']
# 3683                 ['Anglais']
#
#                                             savoir_etre  \
# 0     ['Capacité à prendre des décisions', "Capacité...
# 1     ["Capacité d'analyse", 'Capacité d’écoute', 'C...
# 2                         ['Aucun savoir-être attendu']
# 3                     ["Esprit d'équipe", 'Leadership']
# 4                         ['Aucun savoir-être attendu']
# ...                                                 ...
# 3679  ["Esprit d'équipe", 'Rigueur', "Sens de l'orga...
# 3680  ['Autonomie', 'Capacité de communication', 'Fo...
# 3681  ['Agilité', 'Ambition', 'Audace', 'Créativité'...
# 3682  ['Autonomie', 'Dynamisme', "Esprit d'équipe", ...
# 3683  ['Autonomie', "Capacité d'analyse", 'Capacité ...
#
#                                            savoir_faire  \
# 0     ['Algorithme', 'Amazon Web Services', 'Base de...
# 1     ['Analyse de données', 'Analyse technique', 'D...
# 2     ['Analyse de données', 'Analyse financière', '...
# 3     ['Communication', 'Gestion de projet', 'Règlem...
# 4                        ['Aucun savoir-faire attendu']
# ...                                                 ...
# 3679  ['Administration système et réseau', 'Analyse ...
# 3680  ['C sharp', 'C++', 'Management des personnes',...
# 3681  ['Réseau électrique', 'Accompagnement du clien...
# 3682  ['Qualité', 'Archivage', 'Certification ITIL',...
# 3683  ['Linux', 'Accompagnement du client', 'Gestion...
#
#                                   descriptif_entreprise nombre_posts duree  \
# 0     AI&Data est une Agence Data sur trois domaines...           1   None
# 1     La société BLUE CONSULTING, Entreprise de serv...           1   None
# 2     La Caf des Hauts-de-Seine, c’est...\n630 colla...           1   None
# 3     Avanade France, des experts Microsoft et ses p...           1   None
# 4     MAKE IT HAPPEN - Depuis 2001, PREREQUIS mise s...           1   None
# ...                                                 ...          ...   ...
# 3679  Le SDIS 42 (Service Départemental d'Incendie e...           1   None
# 3680  SILEANE spécialiste en ROBOTIQUE et VISION, en...           1   None
# 3681  Akkodis, est un acteur mondial de l'ingénierie...           1   None
# 3682  Leader européen dans le domaine des explosifs ...           1   None
# 3683  Api & You, agence conseil, communication et e-...           1   None
#
#                      ville code_postal     departement
# 0     Boulogne-Billancourt          92  Hauts-de-seine
# 1         Levallois-Perret          92  Hauts-de-seine
# 2                 Nanterre          92  Hauts-de-seine
# 3      Issy-les-Moulineaux          92  Hauts-de-seine
# 4        Neuilly-sur-Seine          92  Hauts-de-seine
# ...                    ...         ...             ...
# 3679         Saint-Étienne          42           Loire
# 3680         Saint-Étienne          42           Loire
# 3681                Roanne          42           Loire
# 3682              Bergerac          24        Dordogne
# 3683               Poligny          39            Jura
#
# [3684 rows x 23 columns]
