# %% [markdown]
# # Importation des bibliothéques

# %%
import pandas as pd

# %% [markdown]
# # Chargement des Données

# %%
df = pd.read_csv("Scrapped_Data/Data_Apec_data/Apec_data_total.csv")
df
# Out:
#                                  entreprise            type_contrat  \
# 0                      ECM (Direction Nord)                1 \n CDI
# 1                                 SP SEARCH                1 \n CDI
# 2                                 SP SEARCH                1 \n CDI
# 3                                 SP SEARCH                1 \n CDI
# 4                                 SP SEARCH                1 \n CDI
# ...                                     ...                     ...
# 6130     DIRECTION GENERALE DES ENTREPRISES  1 \n CDD \n de 36 mois
# 6131                             SEMAPHORES                1 \n CDI
# 6132  INVIVO RETAIL PRODUCTION MARCHANDISES                1 \n CDI
# 6133                               SIBYLONE                1 \n CDI
# 6134                                 PARLYM                1 \n CDI
#
#              deparetement       date_publication          date_mise_a_jour  \
# ...

# %%
filtered_df = df[df['metier'].str.contains('data|Data|bases de données|Business analyst|Web analyst|Ingénieur développement BI')]
filtered_df
# Out:
#                                  entreprise            type_contrat  \
# 27                           PAGE PERSONNEL  1 \n CDD \n de 12 mois
# 32        MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 34        MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 36        MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# 39        MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# ...                                     ...                     ...
# 6102                        ALTARES - D & B                1 \n CDI
# 6116          Armée de l'Air et de l'Espace  1 \n CDD \n de 18 mois
# 6123                             APOLLO SSC                1 \n CDI
# 6132  INVIVO RETAIL PRODUCTION MARCHANDISES                1 \n CDI
# 6133                               SIBYLONE                1 \n CDI
#
#          deparetement       date_publication          date_mise_a_jour  \
# 27        Clichy - 92  Publiée le 16/03/2024  Actualisée le 16/03/2024
# ...

# %%
type_metier_filtred_unique = filtered_df["metier"].unique()
type_metier_filtred_unique
# Out:
# array(['Data analyst', 'Chief Data Officer', 'Business analyst',
#        'Data engineer', 'Administrateur data center',
#        'Ingénieur développement BI', 'Administrateur de bases de données',
#        'Data scientist', 'Architecte Big Data', 'Web analyst'],
#       dtype=object)

# %%
filtered_df.to_csv("Scrapped_Data/Data_Apec_data/Apec_data_filtred.csv" , index=False)
