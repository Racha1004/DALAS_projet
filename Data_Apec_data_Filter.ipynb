# %% [markdown]
# # Importation des bibliothéques

# %%
import pandas as pd

# %% [markdown]
# # Chargement des Données

# %%
df = pd.read_csv("Scrapped_Data/Data_Apec_data/Apec_data_total.csv")
df
# Out:
#                                  entreprise            type_contrat  \
# 0                      ECM (Direction Nord)                1 \n CDI
# 1                                 SP SEARCH                1 \n CDI
# 2                                 SP SEARCH                1 \n CDI
# 3                                 SP SEARCH                1 \n CDI
# 4                                 SP SEARCH                1 \n CDI
# ...                                     ...                     ...
# 6130     DIRECTION GENERALE DES ENTREPRISES  1 \n CDD \n de 36 mois
# 6131                             SEMAPHORES                1 \n CDI
# 6132  INVIVO RETAIL PRODUCTION MARCHANDISES                1 \n CDI
# 6133                               SIBYLONE                1 \n CDI
# 6134                                 PARLYM                1 \n CDI
#
#              deparetement       date_publication          date_mise_a_jour  \
# ...

# %%
type_metier_unique = df["metier"].unique()
type_metier_unique
# Out:
# array(['Chef de projet informatique décisionnelle',
#        'Ingénieur sécurité informatique',
#        'Consultant technique progiciel', 'Ingénieur test et recettes',
#        'Architecte infrastructures', 'Responsable sécurité informatique',
#        'Chef de projet informatique', 'Category manager', 'Développeur',
#        'Key account manager', 'Ingénieur R&D',
#        "Consultant maîtrise d'ouvrage",
#        'Ingénieur de production industrielle', 'Ingénieur mécanique',
#        'Ingénieur qualité', 'Chef de produit digital',
#        'Analyste financier', 'Gestionnaire de paie', 'Data analyst',
#        'Ingénieur système', 'Ingénieur génie électrique',
#        'Chief Data Officer', 'Business analyst',
#        'Architecte développement', 'Data engineer',
#        'Administrateur data center', 'Orthophoniste',
#        'Responsable qualité', 'Formateur', 'Comptable',
#        "Directeur des systèmes d'information", 'Administrateur système',
# ...

# %%
type_metier_filtred_unique = type_metier_unique["metier"].unique()
type_metier_filtred_unique
# Out:
# array(['Data analyst', 'Chief Data Officer', 'Business analyst',
#        'Data engineer', 'Administrateur data center',
#        'Ingénieur développement BI', 'Administrateur de bases de données',
#        'Data scientist', 'Architecte Big Data', 'Web analyst'],
#       dtype=object)

# %%
filtered_df.to_csv("Scrapped_Data/Data_Apec_data/Apec_data_filtred.csv" , index=False)

# %%
df2 = pd.read_csv("Scrapped_Data/ancienne_data/Apec_data_total.csv")
filtered_df2 = df2[df2['metier'].str.contains('data|Data|bases de données|Business analyst|Web analyst|Ingénieur développement BI')]
filtered_df2
# Out:
#                             entreprise type_contrat  \
# 0                              AI&Data     1 \n CDI
# 1                           VR CONSEIL     1 \n CDI
# 2                                MACIF     1 \n CDI
# 3                               MYDRAL     1 \n CDI
# 4    MICHAEL PAGE INTERNATIONAL FRANCE     1 \n CDI
# ..                                 ...          ...
# 989                      NEXT DECISION     1 \n CDI
# 991                           Adsearch     1 \n CDI
# 996    Soft Computing - Epsilon France     1 \n CDI
# 997                Segula Technologies     1 \n CDI
# 999                            POLARYS     1 \n CDI
#
#                   deparetement       date_publication  \
# 0    Boulogne-Billancourt - 92  Publiée le 01/02/2024
# 1                Paris 09 - 75  Publiée le 14/12/2023
# 2                   Niort - 79  Publiée le 07/02/2024
# 3                Paris 02 - 75  Publiée le 05/02/2024
# 4                  Rennes - 35  Publiée le 27/01/2024
# ...

# %%
type_metier_filtred_unique = filtered_df2["metier"].unique()
type_metier_filtred_unique
# Out:
# array(['Data analyst', 'Data engineer', 'Chief Data Officer',
#        'Administrateur de bases de données', 'Architecte Big Data',
#        'Data scientist', 'Business analyst', 'Ingénieur développement BI',
#        'Administrateur data center'], dtype=object)

# %%
filtered_df2.to_csv("Scrapped_Data/ancienne_data/Apec_data_filtred.csv" , index=False)

# %% [markdown]
# # Filtrage des données qu'on a mergé -> Tous les métiers

# %%
df = pd.read_csv("Scrapped_Data/Merge_data_cybSec_ancienne/Apec_data_total_merged.csv")
df
# Out:
#                              entreprise            type_contrat  \
# 0                               AI&Data                1 \n CDI
# 1                            VR CONSEIL                1 \n CDI
# 2                                 MACIF                1 \n CDI
# 3                                MYDRAL                1 \n CDI
# 4     MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# ...                                 ...                     ...
# 9207                    Q ENERGY France                1 \n CDI
# 9208               REGION ILE DE FRANCE  1 \n CDD \n de 36 mois
# 9209                            ARTELIA                1 \n CDI
# 9210               GMBA Walter Allinial                1 \n CDI
# 9211            DR PARIS IDF CENTRE-EST  1 \n CDD \n de 24 mois
#
#                    deparetement       date_publication  \
# 0     Boulogne-Billancourt - 92  Publiée le 01/02/2024
# 1                 Paris 09 - 75  Publiée le 14/12/2023
# ...

# %%
metiers_a_filtrer = ['Data analyst', 'Chief Data Officer', 'Business analyst', 'Data engineer', 'Administrateur data center', 'Ingénieur développement BI', 'Administrateur de bases de données', 'Data scientist', 'Architecte Big Data', 'Web analyst','Chef de projet informatique décisionnelle', 'Ingénieur sécurité informatique', 'Ingénieur test et recettes', 'Architecte infrastructures', 'Responsable sécurité informatique',  'Chef de projet informatique', 'Développeur', 'Ingénieur système', 'Architecte développement', 'Administrateur système', 'Business developer', 'Ingénieur réseaux','Ingénieur informatique embarquée','Ingénieur traitement du signal' , 'Directeur de projets informatiques']

# Filtrer les lignes où la colonne "métier" contient l'un des métiers de la liste
df_filtre = df[df['metier'].isin(metiers_a_filtrer)]

# %%
type_metier_filtred_unique = df_filtre["metier"].unique()
type_metier_filtred_unique
# Out:
# array(['Data analyst', 'Data engineer', 'Chief Data Officer',
#        'Ingénieur sécurité informatique',
#        'Chef de projet informatique décisionnelle',
#        'Administrateur de bases de données',
#        'Chef de projet informatique', 'Architecte Big Data',
#        'Data scientist', 'Business analyst', 'Ingénieur développement BI',
#        'Architecte développement', 'Architecte infrastructures',
#        'Administrateur data center', 'Développeur', 'Ingénieur système',
#        'Business developer', 'Ingénieur réseaux',
#        'Directeur de projets informatiques', 'Administrateur système',
#        'Ingénieur informatique embarquée', 'Ingénieur test et recettes',
#        'Responsable sécurité informatique',
#        'Ingénieur traitement du signal', 'Web analyst'], dtype=object)

# %%
df_filtre
# Out:
#                              entreprise            type_contrat  \
# 0                               AI&Data                1 \n CDI
# 1                            VR CONSEIL                1 \n CDI
# 2                                 MACIF                1 \n CDI
# 3                                MYDRAL                1 \n CDI
# 4     MICHAEL PAGE INTERNATIONAL FRANCE                1 \n CDI
# ...                                 ...                     ...
# 9172                             MONEXT                1 \n CDI
# 9187                          CDISCOUNT                1 \n CDI
# 9199                  AMARIS FRANCE SAS                1 \n CDI
# 9208               REGION ILE DE FRANCE  1 \n CDD \n de 36 mois
# 9211            DR PARIS IDF CENTRE-EST  1 \n CDD \n de 24 mois
#
#                    deparetement       date_publication  \
# 0     Boulogne-Billancourt - 92  Publiée le 01/02/2024
# 1                 Paris 09 - 75  Publiée le 14/12/2023
# ...

# %%
df_filtre.to_csv("Scrapped_Data/Merge_data_cybSec_ancienne/Apec_data_total_merged_filred.csv" , index=False)
